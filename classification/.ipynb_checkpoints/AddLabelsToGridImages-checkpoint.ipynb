# %%
def replace_label_with_int(x):
    return {
        'EPEA*+ID Runtime': 0,
        'MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime':1,
        'ICTS 3E +ID Runtime':2,
        'A*+OD+ID Runtime':3,
        'Basic-CBS/(A*/SIC)+ID Runtime':4
    }[x]


experiments_dir = "graph"
pictures_dir = "edgelists/"+experiments_dir
jpg_pictures_dir = pictures_dir +"/jpg"

# %%
def obstacle_ratio_to_num(ratio, rows):
    print(ratio, rows)
    if(ratio==0):
        return 0
    return int((rows*rows)*(ratio/100))
obstacle_ratio_to_num(30, 140)
# Out:
# 30 140
# 5880

# %% [markdown]
# ## Let's rename the pngs with labels ##

# %%
import glob
import pandas as pd
import os
experiments_dir = "nathan_AllData"
pictures_dir = "edgelists/new_format/"+experiments_dir
df = pd.read_csv("data/from-azure/"+experiments_dir+"-labelled.csv")

# THIS USED FOR REPLACING MAPF ALGORITHM NAMES WITH 0-4 VALUES
df['Ylabel'] = df['Y'].apply(replace_label_with_int)
for file in list(glob.glob(pictures_dir+"/*.png")):
    if 'label' in file:
        continue
    
#     if 'Instance' not in file:
# #         print("Skipping",file)
#         continue
    
    instance_details = file.split('\\')[1].split('-')
    gridsize = instance_details[1]
    obstacle_ratio = instance_details[2]
    num_agents = instance_details[3]
    instance_id = instance_details[4].split('.')[0]
    
    orig_filename =file.split('\\')[1]
    print(gridsize, obstacle_ratio, num_agents, instance_id, file)

    label = df[(df.NumOfAgents==int(num_agents)) & 
               (df.InstanceId == int(instance_id)) &
                (df.GridRows == int(gridsize)) &
               (df.NumOfObstacles == obstacle_ratio_to_num(int(obstacle_ratio), int(gridsize)))]['Ylabel'].values[0]
    print(label)
    new_filename = orig_filename.split('.')[0] +"-label"+ str(label)+".png"
    print(num_agents, instance_id)
    print("Rename", orig_filename, "to", new_filename)
    os.rename(pictures_dir+"/"+orig_filename, pictures_dir+"/"+new_filename)
#     print(df[(df['NumOfAgents']==num_agents) & (df['InstanceId']==instance_id)]['Y'])
# Out:
# 16 16 1 1 edgelists/new_format/nathan_AllData\empty-16-16-1-1.png
# 16 16
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-00cedadaf68a> in <module>
#      28                (df.InstanceId == int(instance_id)) &
#      29                 (df.GridRows == int(gridsize)) &
# ---> 30                (df.NumOfObstacles == obstacle_ratio_to_num(int(obstacle_ratio), int(gridsize)))]['Ylabel'].values[0]
#      31     print(label)
#      32     new_filename = orig_filename.split('.')[0] +"-label"+ str(label)+".png"
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# ## THE SAME FOR KIVA MAPS ##

# %%
import glob
import pandas as pd

experiments_dir = "nathan_AllData"
pictures_dir = "edgelists/new_format/"+experiments_dir
df = pd.read_csv("data/from-azure/"+experiments_dir+"-labelled.csv")

# THIS USED FOR REPLACING MAPF ALGORITHM NAMES WITH 0-4 VALUES
df['Ylabel'] = df['Y'].apply(replace_label_with_int)
for file in list(glob.glob(pictures_dir+"/*.png")):
    if 'label' in file:
        continue
    
#     if 'Instance' in file:
# #         print("Skipping",file)
#         continue
    
    instance_details = file.split('\\')[1].split('-')
    grid_name = '-'.join(instance_details[:-2])
    num_agents = instance_details[-2]
    instance_id = instance_details[-1].split('.')[0]

    orig_filename =file.split('\\')[1]
    print(grid_name, num_agents, instance_id, file)

    label = df[(df.NumOfAgents==int(num_agents)) & 
               (df.InstanceId == int(instance_id)) &
               (df.GridName == grid_name)]['Ylabel'].values[0]
    print(label)
    new_filename = orig_filename.split('.')[0] +"-label"+ str(label)+".png"
    print(num_agents, instance_id)
    print("Rename", orig_filename, "to", new_filename)
    os.rename(pictures_dir+"/"+orig_filename, pictures_dir+"/"+new_filename)
# Out:
# maze-128-128-10 1 5 edgelists/new_format/nathan_AllData\maze-128-128-10-1-5.png
# 1
# 1 5
# Rename maze-128-128-10-1-5.png to maze-128-128-10-1-5-label1.png
# maze-128-128-10 1 6 edgelists/new_format/nathan_AllData\maze-128-128-10-1-6.png
# 1
# 1 6
# Rename maze-128-128-10-1-6.png to maze-128-128-10-1-6-label1.png
# maze-128-128-10 10 5 edgelists/new_format/nathan_AllData\maze-128-128-10-10-5.png
# 1
# 10 5
# Rename maze-128-128-10-10-5.png to maze-128-128-10-10-5-label1.png
# maze-128-128-10 11 5 edgelists/new_format/nathan_AllData\maze-128-128-10-11-5.png
# 1
# 11 5
# Rename maze-128-128-10-11-5.png to maze-128-128-10-11-5-label1.png
# maze-128-128-10 12 5 edgelists/new_format/nathan_AllData\maze-128-128-10-12-5.png
# 0
# 12 5
# Rename maze-128-128-10-12-5.png to maze-128-128-10-12-5-label0.png
# maze-128-128-10 13 5 edgelists/new_format/nathan_AllData\maze-128-128-10-13-5.png
# 4
# 13 5
# Rename maze-128-128-10-13-5.png to maze-128-128-10-13-5-label4.png
# maze-128-128-10 14 5 edgelists/new_format/nathan_AllData\maze-128-128-10-14-5.png
# 3
# 14 5
# Rename maze-128-128-10-14-5.png to maze-128-128-10-14-5-label3.png
# maze-128-128-10 2 5 edgelists/new_format/nathan_AllData\maze-128-128-10-2-5.png
# 4
# 2 5
# Rename maze-128-128-10-2-5.png to maze-128-128-10-2-5-label4.png
# maze-128-128-10 2 6 edgelists/new_format/nathan_AllData\maze-128-128-10-2-6.png
# 1
# 2 6
# Rename maze-128-128-10-2-6.png to maze-128-128-10-2-6-label1.png
# maze-128-128-10 3 5 edgelists/new_format/nathan_AllData\maze-128-128-10-3-5.png
# 3
# 3 5
# Rename maze-128-128-10-3-5.png to maze-128-128-10-3-5-label3.png
# maze-128-128-10 3 6 edgelists/new_format/nathan_AllData\maze-128-128-10-3-6.png
# 1
# 3 6
# Rename maze-128-128-10-3-6.png to maze-128-128-10-3-6-label1.png
# maze-128-128-10 4 5 edgelists/new_format/nathan_AllData\maze-128-128-10-4-5.png
# 1
# 4 5
# Rename maze-128-128-10-4-5.png to maze-128-128-10-4-5-label1.png
# maze-128-128-10 4 6 edgelists/new_format/nathan_AllData\maze-128-128-10-4-6.png
# 1
# 4 6
# Rename maze-128-128-10-4-6.png to maze-128-128-10-4-6-label1.png
# maze-128-128-10 5 5 edgelists/new_format/nathan_AllData\maze-128-128-10-5-5.png
# 1
# 5 5
# Rename maze-128-128-10-5-5.png to maze-128-128-10-5-5-label1.png
# maze-128-128-10 5 6 edgelists/new_format/nathan_AllData\maze-128-128-10-5-6.png
# 1
# 5 6
# Rename maze-128-128-10-5-6.png to maze-128-128-10-5-6-label1.png
# maze-128-128-10 6 5 edgelists/new_format/nathan_AllData\maze-128-128-10-6-5.png
# 1
# 6 5
# Rename maze-128-128-10-6-5.png to maze-128-128-10-6-5-label1.png
# maze-128-128-10 6 6 edgelists/new_format/nathan_AllData\maze-128-128-10-6-6.png
# 4
# 6 6
# Rename maze-128-128-10-6-6.png to maze-128-128-10-6-6-label4.png
# maze-128-128-10 7 5 edgelists/new_format/nathan_AllData\maze-128-128-10-7-5.png
# 1
# 7 5
# Rename maze-128-128-10-7-5.png to maze-128-128-10-7-5-label1.png
# maze-128-128-10 7 6 edgelists/new_format/nathan_AllData\maze-128-128-10-7-6.png
# 4
# 7 6
# Rename maze-128-128-10-7-6.png to maze-128-128-10-7-6-label4.png
# maze-128-128-10 8 5 edgelists/new_format/nathan_AllData\maze-128-128-10-8-5.png
# 1
# 8 5
# Rename maze-128-128-10-8-5.png to maze-128-128-10-8-5-label1.png
# maze-128-128-10 8 6 edgelists/new_format/nathan_AllData\maze-128-128-10-8-6.png
# 4
# 8 6
# Rename maze-128-128-10-8-6.png to maze-128-128-10-8-6-label4.png
# maze-128-128-10 9 5 edgelists/new_format/nathan_AllData\maze-128-128-10-9-5.png
# 1
# 9 5
# Rename maze-128-128-10-9-5.png to maze-128-128-10-9-5-label1.png
# maze-128-128-10 9 6 edgelists/new_format/nathan_AllData\maze-128-128-10-9-6.png
# 4
# 9 6
# Rename maze-128-128-10-9-6.png to maze-128-128-10-9-6-label4.png
# maze-128-128-2 1 5 edgelists/new_format/nathan_AllData\maze-128-128-2-1-5.png
# 1
# 1 5
# Rename maze-128-128-2-1-5.png to maze-128-128-2-1-5-label1.png
# maze-128-128-2 1 6 edgelists/new_format/nathan_AllData\maze-128-128-2-1-6.png
# 1
# 1 6
# Rename maze-128-128-2-1-6.png to maze-128-128-2-1-6-label1.png
# maze-128-128-2 10 5 edgelists/new_format/nathan_AllData\maze-128-128-2-10-5.png
# 1
# 10 5
# Rename maze-128-128-2-10-5.png to maze-128-128-2-10-5-label1.png
# maze-128-128-2 10 6 edgelists/new_format/nathan_AllData\maze-128-128-2-10-6.png
# 4
# 10 6
# Rename maze-128-128-2-10-6.png to maze-128-128-2-10-6-label4.png
# maze-128-128-2 11 5 edgelists/new_format/nathan_AllData\maze-128-128-2-11-5.png
# 1
# 11 5
# Rename maze-128-128-2-11-5.png to maze-128-128-2-11-5-label1.png
# maze-128-128-2 11 6 edgelists/new_format/nathan_AllData\maze-128-128-2-11-6.png
# 3
# 11 6
# Rename maze-128-128-2-11-6.png to maze-128-128-2-11-6-label3.png
# maze-128-128-2 12 5 edgelists/new_format/nathan_AllData\maze-128-128-2-12-5.png
# 1
# 12 5
# Rename maze-128-128-2-12-5.png to maze-128-128-2-12-5-label1.png
# maze-128-128-2 13 5 edgelists/new_format/nathan_AllData\maze-128-128-2-13-5.png
# 1
# 13 5
# Rename maze-128-128-2-13-5.png to maze-128-128-2-13-5-label1.png
# maze-128-128-2 14 5 edgelists/new_format/nathan_AllData\maze-128-128-2-14-5.png
# 1
# 14 5
# Rename maze-128-128-2-14-5.png to maze-128-128-2-14-5-label1.png
# maze-128-128-2 15 5 edgelists/new_format/nathan_AllData\maze-128-128-2-15-5.png
# 1
# 15 5
# Rename maze-128-128-2-15-5.png to maze-128-128-2-15-5-label1.png
# maze-128-128-2 16 5 edgelists/new_format/nathan_AllData\maze-128-128-2-16-5.png
# 0
# 16 5
# Rename maze-128-128-2-16-5.png to maze-128-128-2-16-5-label0.png
# maze-128-128-2 17 5 edgelists/new_format/nathan_AllData\maze-128-128-2-17-5.png
# 3
# 17 5
# Rename maze-128-128-2-17-5.png to maze-128-128-2-17-5-label3.png
# maze-128-128-2 18 5 edgelists/new_format/nathan_AllData\maze-128-128-2-18-5.png
# 2
# 18 5
# Rename maze-128-128-2-18-5.png to maze-128-128-2-18-5-label2.png
# maze-128-128-2 19 5 edgelists/new_format/nathan_AllData\maze-128-128-2-19-5.png
# 1
# 19 5
# Rename maze-128-128-2-19-5.png to maze-128-128-2-19-5-label1.png
# maze-128-128-2 2 5 edgelists/new_format/nathan_AllData\maze-128-128-2-2-5.png
# 1
# 2 5
# Rename maze-128-128-2-2-5.png to maze-128-128-2-2-5-label1.png
# maze-128-128-2 2 6 edgelists/new_format/nathan_AllData\maze-128-128-2-2-6.png
# 1
# 2 6
# Rename maze-128-128-2-2-6.png to maze-128-128-2-2-6-label1.png
# maze-128-128-2 3 5 edgelists/new_format/nathan_AllData\maze-128-128-2-3-5.png
# 1
# 3 5
# Rename maze-128-128-2-3-5.png to maze-128-128-2-3-5-label1.png
# maze-128-128-2 3 6 edgelists/new_format/nathan_AllData\maze-128-128-2-3-6.png
# 1
# 3 6
# Rename maze-128-128-2-3-6.png to maze-128-128-2-3-6-label1.png
# maze-128-128-2 4 5 edgelists/new_format/nathan_AllData\maze-128-128-2-4-5.png
# 1
# 4 5
# Rename maze-128-128-2-4-5.png to maze-128-128-2-4-5-label1.png
# maze-128-128-2 4 6 edgelists/new_format/nathan_AllData\maze-128-128-2-4-6.png
# 1
# 4 6
# Rename maze-128-128-2-4-6.png to maze-128-128-2-4-6-label1.png
# maze-128-128-2 5 5 edgelists/new_format/nathan_AllData\maze-128-128-2-5-5.png
# 1
# 5 5
# Rename maze-128-128-2-5-5.png to maze-128-128-2-5-5-label1.png
# maze-128-128-2 5 6 edgelists/new_format/nathan_AllData\maze-128-128-2-5-6.png
# 1
# 5 6
# Rename maze-128-128-2-5-6.png to maze-128-128-2-5-6-label1.png
# maze-128-128-2 6 5 edgelists/new_format/nathan_AllData\maze-128-128-2-6-5.png
# 1
# 6 5
# Rename maze-128-128-2-6-5.png to maze-128-128-2-6-5-label1.png
# maze-128-128-2 6 6 edgelists/new_format/nathan_AllData\maze-128-128-2-6-6.png
# 1
# 6 6
# Rename maze-128-128-2-6-6.png to maze-128-128-2-6-6-label1.png
# maze-128-128-2 7 5 edgelists/new_format/nathan_AllData\maze-128-128-2-7-5.png
# 1
# 7 5
# Rename maze-128-128-2-7-5.png to maze-128-128-2-7-5-label1.png
# maze-128-128-2 7 6 edgelists/new_format/nathan_AllData\maze-128-128-2-7-6.png
# 1
# 7 6
# Rename maze-128-128-2-7-6.png to maze-128-128-2-7-6-label1.png
# maze-128-128-2 8 5 edgelists/new_format/nathan_AllData\maze-128-128-2-8-5.png
# 1
# 8 5
# Rename maze-128-128-2-8-5.png to maze-128-128-2-8-5-label1.png
# maze-128-128-2 8 6 edgelists/new_format/nathan_AllData\maze-128-128-2-8-6.png
# 1
# 8 6
# Rename maze-128-128-2-8-6.png to maze-128-128-2-8-6-label1.png
# maze-128-128-2 9 5 edgelists/new_format/nathan_AllData\maze-128-128-2-9-5.png
# 1
# 9 5
# Rename maze-128-128-2-9-5.png to maze-128-128-2-9-5-label1.png
# maze-128-128-2 9 6 edgelists/new_format/nathan_AllData\maze-128-128-2-9-6.png
# 4
# 9 6
# Rename maze-128-128-2-9-6.png to maze-128-128-2-9-6-label4.png
# maze-32-32-2 1 5 edgelists/new_format/nathan_AllData\maze-32-32-2-1-5.png
# 1
# 1 5
# Rename maze-32-32-2-1-5.png to maze-32-32-2-1-5-label1.png
# maze-32-32-2 1 6 edgelists/new_format/nathan_AllData\maze-32-32-2-1-6.png
# 1
# 1 6
# Rename maze-32-32-2-1-6.png to maze-32-32-2-1-6-label1.png
# maze-32-32-2 10 5 edgelists/new_format/nathan_AllData\maze-32-32-2-10-5.png
# 4
# 10 5
# Rename maze-32-32-2-10-5.png to maze-32-32-2-10-5-label4.png
# maze-32-32-2 10 6 edgelists/new_format/nathan_AllData\maze-32-32-2-10-6.png
# 3
# 10 6
# Rename maze-32-32-2-10-6.png to maze-32-32-2-10-6-label3.png
# maze-32-32-2 11 5 edgelists/new_format/nathan_AllData\maze-32-32-2-11-5.png
# 4
# 11 5
# Rename maze-32-32-2-11-5.png to maze-32-32-2-11-5-label4.png
# maze-32-32-2 11 6 edgelists/new_format/nathan_AllData\maze-32-32-2-11-6.png
# 3
# 11 6
# Rename maze-32-32-2-11-6.png to maze-32-32-2-11-6-label3.png
# maze-32-32-2 12 5 edgelists/new_format/nathan_AllData\maze-32-32-2-12-5.png
# 3
# 12 5
# Rename maze-32-32-2-12-5.png to maze-32-32-2-12-5-label3.png
# maze-32-32-2 12 6 edgelists/new_format/nathan_AllData\maze-32-32-2-12-6.png
# 0
# 12 6
# Rename maze-32-32-2-12-6.png to maze-32-32-2-12-6-label0.png
# maze-32-32-2 13 6 edgelists/new_format/nathan_AllData\maze-32-32-2-13-6.png
# 0
# 13 6
# Rename maze-32-32-2-13-6.png to maze-32-32-2-13-6-label0.png
# maze-32-32-2 14 6 edgelists/new_format/nathan_AllData\maze-32-32-2-14-6.png
# 2
# 14 6
# Rename maze-32-32-2-14-6.png to maze-32-32-2-14-6-label2.png
# maze-32-32-2 15 6 edgelists/new_format/nathan_AllData\maze-32-32-2-15-6.png
# 2
# 15 6
# Rename maze-32-32-2-15-6.png to maze-32-32-2-15-6-label2.png
# maze-32-32-2 16 6 edgelists/new_format/nathan_AllData\maze-32-32-2-16-6.png
# 2
# 16 6
# Rename maze-32-32-2-16-6.png to maze-32-32-2-16-6-label2.png
# maze-32-32-2 17 6 edgelists/new_format/nathan_AllData\maze-32-32-2-17-6.png
# 3
# 17 6
# Rename maze-32-32-2-17-6.png to maze-32-32-2-17-6-label3.png
# maze-32-32-2 2 5 edgelists/new_format/nathan_AllData\maze-32-32-2-2-5.png
# 1
# 2 5
# Rename maze-32-32-2-2-5.png to maze-32-32-2-2-5-label1.png
# maze-32-32-2 2 6 edgelists/new_format/nathan_AllData\maze-32-32-2-2-6.png
# 1
# 2 6
# Rename maze-32-32-2-2-6.png to maze-32-32-2-2-6-label1.png
# maze-32-32-2 3 5 edgelists/new_format/nathan_AllData\maze-32-32-2-3-5.png
# 1
# 3 5
# Rename maze-32-32-2-3-5.png to maze-32-32-2-3-5-label1.png
# maze-32-32-2 3 6 edgelists/new_format/nathan_AllData\maze-32-32-2-3-6.png
# 1
# 3 6
# Rename maze-32-32-2-3-6.png to maze-32-32-2-3-6-label1.png
# maze-32-32-2 4 5 edgelists/new_format/nathan_AllData\maze-32-32-2-4-5.png
# 1
# 4 5
# Rename maze-32-32-2-4-5.png to maze-32-32-2-4-5-label1.png
# maze-32-32-2 4 6 edgelists/new_format/nathan_AllData\maze-32-32-2-4-6.png
# 1
# 4 6
# Rename maze-32-32-2-4-6.png to maze-32-32-2-4-6-label1.png
# maze-32-32-2 5 5 edgelists/new_format/nathan_AllData\maze-32-32-2-5-5.png
# 1
# 5 5
# Rename maze-32-32-2-5-5.png to maze-32-32-2-5-5-label1.png
# maze-32-32-2 5 6 edgelists/new_format/nathan_AllData\maze-32-32-2-5-6.png
# 1
# 5 6
# Rename maze-32-32-2-5-6.png to maze-32-32-2-5-6-label1.png
# maze-32-32-2 6 5 edgelists/new_format/nathan_AllData\maze-32-32-2-6-5.png
# 1
# 6 5
# Rename maze-32-32-2-6-5.png to maze-32-32-2-6-5-label1.png
# maze-32-32-2 6 6 edgelists/new_format/nathan_AllData\maze-32-32-2-6-6.png
# 1
# 6 6
# Rename maze-32-32-2-6-6.png to maze-32-32-2-6-6-label1.png
# maze-32-32-2 7 5 edgelists/new_format/nathan_AllData\maze-32-32-2-7-5.png
# 1
# 7 5
# Rename maze-32-32-2-7-5.png to maze-32-32-2-7-5-label1.png
# maze-32-32-2 7 6 edgelists/new_format/nathan_AllData\maze-32-32-2-7-6.png
# 1
# 7 6
# Rename maze-32-32-2-7-6.png to maze-32-32-2-7-6-label1.png
# maze-32-32-2 8 5 edgelists/new_format/nathan_AllData\maze-32-32-2-8-5.png
# 1
# 8 5
# Rename maze-32-32-2-8-5.png to maze-32-32-2-8-5-label1.png
# maze-32-32-2 8 6 edgelists/new_format/nathan_AllData\maze-32-32-2-8-6.png
# 1
# 8 6
# Rename maze-32-32-2-8-6.png to maze-32-32-2-8-6-label1.png
# maze-32-32-2 9 5 edgelists/new_format/nathan_AllData\maze-32-32-2-9-5.png
# 4
# 9 5
# Rename maze-32-32-2-9-5.png to maze-32-32-2-9-5-label4.png
# maze-32-32-2 9 6 edgelists/new_format/nathan_AllData\maze-32-32-2-9-6.png
# 0
# 9 6
# Rename maze-32-32-2-9-6.png to maze-32-32-2-9-6-label0.png
# maze-32-32-4 1 5 edgelists/new_format/nathan_AllData\maze-32-32-4-1-5.png
# 1
# 1 5
# Rename maze-32-32-4-1-5.png to maze-32-32-4-1-5-label1.png
# maze-32-32-4 1 6 edgelists/new_format/nathan_AllData\maze-32-32-4-1-6.png
# 4
# 1 6
# Rename maze-32-32-4-1-6.png to maze-32-32-4-1-6-label4.png
# maze-32-32-4 10 6 edgelists/new_format/nathan_AllData\maze-32-32-4-10-6.png
# 0
# 10 6
# Rename maze-32-32-4-10-6.png to maze-32-32-4-10-6-label0.png
# maze-32-32-4 11 6 edgelists/new_format/nathan_AllData\maze-32-32-4-11-6.png
# 1
# 11 6
# Rename maze-32-32-4-11-6.png to maze-32-32-4-11-6-label1.png
# maze-32-32-4 2 5 edgelists/new_format/nathan_AllData\maze-32-32-4-2-5.png
# 1
# 2 5
# Rename maze-32-32-4-2-5.png to maze-32-32-4-2-5-label1.png
# maze-32-32-4 2 6 edgelists/new_format/nathan_AllData\maze-32-32-4-2-6.png
# 1
# 2 6
# Rename maze-32-32-4-2-6.png to maze-32-32-4-2-6-label1.png
# maze-32-32-4 3 5 edgelists/new_format/nathan_AllData\maze-32-32-4-3-5.png
# 1
# 3 5
# Rename maze-32-32-4-3-5.png to maze-32-32-4-3-5-label1.png
# maze-32-32-4 3 6 edgelists/new_format/nathan_AllData\maze-32-32-4-3-6.png
# 1
# 3 6
# Rename maze-32-32-4-3-6.png to maze-32-32-4-3-6-label1.png
# maze-32-32-4 4 5 edgelists/new_format/nathan_AllData\maze-32-32-4-4-5.png
# 0
# 4 5
# Rename maze-32-32-4-4-5.png to maze-32-32-4-4-5-label0.png
# maze-32-32-4 4 6 edgelists/new_format/nathan_AllData\maze-32-32-4-4-6.png
# 1
# 4 6
# Rename maze-32-32-4-4-6.png to maze-32-32-4-4-6-label1.png
# maze-32-32-4 5 5 edgelists/new_format/nathan_AllData\maze-32-32-4-5-5.png
# 1
# 5 5
# Rename maze-32-32-4-5-5.png to maze-32-32-4-5-5-label1.png
# maze-32-32-4 5 6 edgelists/new_format/nathan_AllData\maze-32-32-4-5-6.png
# 1
# 5 6
# Rename maze-32-32-4-5-6.png to maze-32-32-4-5-6-label1.png
# maze-32-32-4 6 5 edgelists/new_format/nathan_AllData\maze-32-32-4-6-5.png
# 1
# 6 5
# Rename maze-32-32-4-6-5.png to maze-32-32-4-6-5-label1.png
# maze-32-32-4 6 6 edgelists/new_format/nathan_AllData\maze-32-32-4-6-6.png
# 1
# 6 6
# Rename maze-32-32-4-6-6.png to maze-32-32-4-6-6-label1.png
# maze-32-32-4 7 5 edgelists/new_format/nathan_AllData\maze-32-32-4-7-5.png
# 1
# 7 5
# Rename maze-32-32-4-7-5.png to maze-32-32-4-7-5-label1.png
# maze-32-32-4 7 6 edgelists/new_format/nathan_AllData\maze-32-32-4-7-6.png
# 1
# 7 6
# Rename maze-32-32-4-7-6.png to maze-32-32-4-7-6-label1.png
# maze-32-32-4 8 6 edgelists/new_format/nathan_AllData\maze-32-32-4-8-6.png
# 1
# 8 6
# Rename maze-32-32-4-8-6.png to maze-32-32-4-8-6-label1.png
# maze-32-32-4 9 6 edgelists/new_format/nathan_AllData\maze-32-32-4-9-6.png
# 3
# 9 6
# Rename maze-32-32-4-9-6.png to maze-32-32-4-9-6-label3.png
# orz900d 1 5 edgelists/new_format/nathan_AllData\orz900d-1-5.png
# 1
# 1 5
# Rename orz900d-1-5.png to orz900d-1-5-label1.png
# orz900d 1 6 edgelists/new_format/nathan_AllData\orz900d-1-6.png
# 1
# 1 6
# Rename orz900d-1-6.png to orz900d-1-6-label1.png
# orz900d 10 5 edgelists/new_format/nathan_AllData\orz900d-10-5.png
# 1
# 10 5
# Rename orz900d-10-5.png to orz900d-10-5-label1.png
# orz900d 10 6 edgelists/new_format/nathan_AllData\orz900d-10-6.png
# 1
# 10 6
# Rename orz900d-10-6.png to orz900d-10-6-label1.png
# orz900d 11 5 edgelists/new_format/nathan_AllData\orz900d-11-5.png
# 1
# 11 5
# Rename orz900d-11-5.png to orz900d-11-5-label1.png
# orz900d 11 6 edgelists/new_format/nathan_AllData\orz900d-11-6.png
# 1
# 11 6
# Rename orz900d-11-6.png to orz900d-11-6-label1.png
# orz900d 12 5 edgelists/new_format/nathan_AllData\orz900d-12-5.png
# 1
# 12 5
# Rename orz900d-12-5.png to orz900d-12-5-label1.png
# orz900d 12 6 edgelists/new_format/nathan_AllData\orz900d-12-6.png
# 1
# 12 6
# Rename orz900d-12-6.png to orz900d-12-6-label1.png
# orz900d 13 5 edgelists/new_format/nathan_AllData\orz900d-13-5.png
# 1
# 13 5
# Rename orz900d-13-5.png to orz900d-13-5-label1.png
# orz900d 13 6 edgelists/new_format/nathan_AllData\orz900d-13-6.png
# 1
# 13 6
# Rename orz900d-13-6.png to orz900d-13-6-label1.png
# orz900d 14 5 edgelists/new_format/nathan_AllData\orz900d-14-5.png
# 1
# 14 5
# Rename orz900d-14-5.png to orz900d-14-5-label1.png
# orz900d 14 6 edgelists/new_format/nathan_AllData\orz900d-14-6.png
# 1
# 14 6
# Rename orz900d-14-6.png to orz900d-14-6-label1.png
# orz900d 15 5 edgelists/new_format/nathan_AllData\orz900d-15-5.png
# 1
# 15 5
# Rename orz900d-15-5.png to orz900d-15-5-label1.png
# orz900d 15 6 edgelists/new_format/nathan_AllData\orz900d-15-6.png
# 1
# 15 6
# Rename orz900d-15-6.png to orz900d-15-6-label1.png
# orz900d 16 5 edgelists/new_format/nathan_AllData\orz900d-16-5.png
# 1
# 16 5
# Rename orz900d-16-5.png to orz900d-16-5-label1.png
# orz900d 16 6 edgelists/new_format/nathan_AllData\orz900d-16-6.png
# 1
# 16 6
# Rename orz900d-16-6.png to orz900d-16-6-label1.png
# orz900d 17 5 edgelists/new_format/nathan_AllData\orz900d-17-5.png
# 1
# 17 5
# Rename orz900d-17-5.png to orz900d-17-5-label1.png
# orz900d 17 6 edgelists/new_format/nathan_AllData\orz900d-17-6.png
# 0
# 17 6
# Rename orz900d-17-6.png to orz900d-17-6-label0.png
# orz900d 18 5 edgelists/new_format/nathan_AllData\orz900d-18-5.png
# 1
# 18 5
# Rename orz900d-18-5.png to orz900d-18-5-label1.png
# orz900d 18 6 edgelists/new_format/nathan_AllData\orz900d-18-6.png
# 2
# 18 6
# Rename orz900d-18-6.png to orz900d-18-6-label2.png
# orz900d 19 5 edgelists/new_format/nathan_AllData\orz900d-19-5.png
# 1
# 19 5
# Rename orz900d-19-5.png to orz900d-19-5-label1.png
# orz900d 19 6 edgelists/new_format/nathan_AllData\orz900d-19-6.png
# 2
# 19 6
# Rename orz900d-19-6.png to orz900d-19-6-label2.png
# orz900d 2 5 edgelists/new_format/nathan_AllData\orz900d-2-5.png
# 1
# 2 5
# Rename orz900d-2-5.png to orz900d-2-5-label1.png
# orz900d 2 6 edgelists/new_format/nathan_AllData\orz900d-2-6.png
# 1
# 2 6
# Rename orz900d-2-6.png to orz900d-2-6-label1.png
# orz900d 20 5 edgelists/new_format/nathan_AllData\orz900d-20-5.png
# 1
# 20 5
# Rename orz900d-20-5.png to orz900d-20-5-label1.png
# orz900d 20 6 edgelists/new_format/nathan_AllData\orz900d-20-6.png
# 2
# 20 6
# Rename orz900d-20-6.png to orz900d-20-6-label2.png
# orz900d 21 5 edgelists/new_format/nathan_AllData\orz900d-21-5.png
# 1
# 21 5
# Rename orz900d-21-5.png to orz900d-21-5-label1.png
# orz900d 21 6 edgelists/new_format/nathan_AllData\orz900d-21-6.png
# 2
# 21 6
# Rename orz900d-21-6.png to orz900d-21-6-label2.png
# orz900d 22 5 edgelists/new_format/nathan_AllData\orz900d-22-5.png
# 1
# 22 5
# Rename orz900d-22-5.png to orz900d-22-5-label1.png
# orz900d 22 6 edgelists/new_format/nathan_AllData\orz900d-22-6.png
# 2
# 22 6
# Rename orz900d-22-6.png to orz900d-22-6-label2.png
# orz900d 23 5 edgelists/new_format/nathan_AllData\orz900d-23-5.png
# 1
# 23 5
# Rename orz900d-23-5.png to orz900d-23-5-label1.png
# orz900d 23 6 edgelists/new_format/nathan_AllData\orz900d-23-6.png
# 3
# 23 6
# Rename orz900d-23-6.png to orz900d-23-6-label3.png
# orz900d 24 5 edgelists/new_format/nathan_AllData\orz900d-24-5.png
# 1
# 24 5
# Rename orz900d-24-5.png to orz900d-24-5-label1.png
# orz900d 24 6 edgelists/new_format/nathan_AllData\orz900d-24-6.png
# 1
# 24 6
# Rename orz900d-24-6.png to orz900d-24-6-label1.png
# orz900d 25 6 edgelists/new_format/nathan_AllData\orz900d-25-6.png
# 2
# 25 6
# Rename orz900d-25-6.png to orz900d-25-6-label2.png
# orz900d 26 6 edgelists/new_format/nathan_AllData\orz900d-26-6.png
# 1
# 26 6
# Rename orz900d-26-6.png to orz900d-26-6-label1.png
# orz900d 27 6 edgelists/new_format/nathan_AllData\orz900d-27-6.png
# 3
# 27 6
# Rename orz900d-27-6.png to orz900d-27-6-label3.png
# orz900d 28 6 edgelists/new_format/nathan_AllData\orz900d-28-6.png
# 1
# 28 6
# Rename orz900d-28-6.png to orz900d-28-6-label1.png
# orz900d 29 6 edgelists/new_format/nathan_AllData\orz900d-29-6.png
# 3
# 29 6
# Rename orz900d-29-6.png to orz900d-29-6-label3.png
# orz900d 3 5 edgelists/new_format/nathan_AllData\orz900d-3-5.png
# 1
# 3 5
# Rename orz900d-3-5.png to orz900d-3-5-label1.png
# orz900d 3 6 edgelists/new_format/nathan_AllData\orz900d-3-6.png
# 1
# 3 6
# Rename orz900d-3-6.png to orz900d-3-6-label1.png
# orz900d 30 6 edgelists/new_format/nathan_AllData\orz900d-30-6.png
# 3
# 30 6
# Rename orz900d-30-6.png to orz900d-30-6-label3.png
# orz900d 4 5 edgelists/new_format/nathan_AllData\orz900d-4-5.png
# 1
# 4 5
# Rename orz900d-4-5.png to orz900d-4-5-label1.png
# orz900d 4 6 edgelists/new_format/nathan_AllData\orz900d-4-6.png
# 1
# 4 6
# Rename orz900d-4-6.png to orz900d-4-6-label1.png
# orz900d 5 5 edgelists/new_format/nathan_AllData\orz900d-5-5.png
# 1
# 5 5
# Rename orz900d-5-5.png to orz900d-5-5-label1.png
# orz900d 5 6 edgelists/new_format/nathan_AllData\orz900d-5-6.png
# 1
# 5 6
# Rename orz900d-5-6.png to orz900d-5-6-label1.png
# orz900d 6 5 edgelists/new_format/nathan_AllData\orz900d-6-5.png
# 1
# 6 5
# Rename orz900d-6-5.png to orz900d-6-5-label1.png
# orz900d 6 6 edgelists/new_format/nathan_AllData\orz900d-6-6.png
# 1
# 6 6
# Rename orz900d-6-6.png to orz900d-6-6-label1.png
# orz900d 7 5 edgelists/new_format/nathan_AllData\orz900d-7-5.png
# 1
# 7 5
# Rename orz900d-7-5.png to orz900d-7-5-label1.png
# orz900d 7 6 edgelists/new_format/nathan_AllData\orz900d-7-6.png
# 1
# 7 6
# Rename orz900d-7-6.png to orz900d-7-6-label1.png
# orz900d 8 5 edgelists/new_format/nathan_AllData\orz900d-8-5.png
# 1
# 8 5
# Rename orz900d-8-5.png to orz900d-8-5-label1.png
# orz900d 8 6 edgelists/new_format/nathan_AllData\orz900d-8-6.png
# 1
# 8 6
# Rename orz900d-8-6.png to orz900d-8-6-label1.png
# orz900d 9 5 edgelists/new_format/nathan_AllData\orz900d-9-5.png
# 1
# 9 5
# Rename orz900d-9-5.png to orz900d-9-5-label1.png
# orz900d 9 6 edgelists/new_format/nathan_AllData\orz900d-9-6.png
# 1
# 9 6
# Rename orz900d-9-6.png to orz900d-9-6-label1.png

# %% [markdown]
# ## IN CASE WE WANT TO REMOVE LABELS FROM IMAGES ##

# %%
import pandas as pd
import glob

experiments_dir = "nathan_AllData"
pictures_dir = "edgelists/new_format/"+experiments_dir
df = pd.read_csv("data/from-azure/"+experiments_dir+"-labelled.csv")

# THIS USED FOR REPLACING MAPF ALGORITHM NAMES WITH 0-4 VALUES
print(pictures_dir)
df['Ylabel'] = df['Y'].apply(replace_label_with_int)
for file in list(glob.glob(pictures_dir+"/*.png")):
    if 'label' in file:
        label_index = file.index('-label')
        os.rename(file, file[:label_index]+file[label_index+len('-label')+1:])
# Out:
# edgelists/new_format/nathan_AllData

# %%
def round_up_to_5(num):
    return str(5 - (int(num) % 5) + int(num))

# %%
def obstacle_density_to_num(density):
    if density=='0.0':
        return 0
    density = density.split('.')[1]
    if len(density) > 2:
        return round_up_to_5(density[:2])
    elif density[0] == '0':
        return density[1:]
    elif len(density) == 1:
        return density+'0'

    return density
obstacle_density_to_num('0.10')
# Out:
# '10'

# %% [markdown]
# ## Writing all labels to file for gexf files ##

# %%
import glob

gexf_path = "C:\\Users\omri\Projects\graph2vec_tf\data\kdd_datasets\mapf"
df['Ylabel'] = df['Y'].apply(replace_label_with_int)

labels_file = open("mapf.Labels", "w")

for index, row in df.iterrows():
    if row.GridName == 'Unknown':
        data = ['Instance',row.GridRows, obstacle_density_to_num(str(row.ObstacleDensity)), row.NumOfAgents, row.InstanceId]
        line = '-'.join(map(str, data)) + '.gexf ' +  str(row['Ylabel'])
    else:
        data = [row.GridName, str(row.NumOfAgents), str(row.InstanceId)]
        line = '-'.join(map(str,data)) +'.gexf ' + str(row['Ylabel'])
    labels_file.write(line + "\n")

labels_file.close()

# %% [markdown]
# ## Create directories for flow_from_directory ##
# ## Code below will divide the png's at pictures_dir to n folders (n classes) ##

# %%
def replace_int_with_label(x):
    return {
        0 : 'EPEA*+ID Runtime',
        1 : 'MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime',
        2: 'ICTS 3E +ID Runtime',
        3: 'A*+OD+ID Runtime',
        4: 'Basic-CBS/(A*/SIC)+ID Runtime',
        5: 'CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime'
    }[x]

# %%
labels = ['EPEA*+ID Runtime',
 'MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime',
 'ICTS 3E +ID Runtime',
 'A*+OD+ID Runtime',
'Basic-CBS/(A*/SIC)+ID Runtime', 
 'CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime']

def folder_from_label(label):
      return {
          'EPEA*+ID Runtime': 'epea',
          'MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime':'ma-cbs',
          'ICTS 3E +ID Runtime':'icts',
          'A*+OD+ID Runtime':'astar',
          'Basic-CBS/(A*/SIC)+ID Runtime':'basic-cbs',
          'CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime': 'cbs-h'
      }[label]

for label in labels:
    os.mkdir(os.path.join(pictures_dir, folder_from_label(label)))

# %%
import glob
import pandas as pd

experiments_dir = "nathan_AllData"
pictures_dir = "edgelists/new_format/"+experiments_dir
df = pd.read_csv("data/from-azure/"+experiments_dir+"-labelled.csv")


# THIS USED FOR REPLACING MAPF ALGORITHM NAMES WITH 0-4 VALUES
df['Ylabel'] = df['Y'].apply(replace_label_with_int)
for file in list(glob.glob(pictures_dir+"/*.png")):
    if 'label' not in file:
        continue
    
    instance_details = file.split('\\')[1].split('-')
    grid_name = '-'.join(instance_details[:-3])
    num_agents = instance_details[-3]
    instance_id = instance_details[-2].split('.')[0]

    orig_filename =file.split('\\')[1]
    print(grid_name, num_agents, instance_id, file)

    label = df[(df.NumOfAgents==int(num_agents)) & 
               (df.InstanceId == int(instance_id)) &
               (df.GridName == grid_name)]['Y'].values[0]
    
    os.rename(file, os.path.join(pictures_dir, folder_from_label(label), orig_filename))
# Out:
# maze-128-128-10 1 5 edgelists/new_format/nathan_AllData\maze-128-128-10-1-5-label1.png
# maze-128-128-10 1 6 edgelists/new_format/nathan_AllData\maze-128-128-10-1-6-label1.png
# maze-128-128-10 10 5 edgelists/new_format/nathan_AllData\maze-128-128-10-10-5-label1.png
# maze-128-128-10 11 5 edgelists/new_format/nathan_AllData\maze-128-128-10-11-5-label1.png
# maze-128-128-10 12 5 edgelists/new_format/nathan_AllData\maze-128-128-10-12-5-label0.png
# maze-128-128-10 13 5 edgelists/new_format/nathan_AllData\maze-128-128-10-13-5-label4.png
# maze-128-128-10 14 5 edgelists/new_format/nathan_AllData\maze-128-128-10-14-5-label3.png
# maze-128-128-10 2 5 edgelists/new_format/nathan_AllData\maze-128-128-10-2-5-label4.png
# maze-128-128-10 2 6 edgelists/new_format/nathan_AllData\maze-128-128-10-2-6-label1.png
# maze-128-128-10 3 5 edgelists/new_format/nathan_AllData\maze-128-128-10-3-5-label3.png
# maze-128-128-10 3 6 edgelists/new_format/nathan_AllData\maze-128-128-10-3-6-label1.png
# maze-128-128-10 4 5 edgelists/new_format/nathan_AllData\maze-128-128-10-4-5-label1.png
# maze-128-128-10 4 6 edgelists/new_format/nathan_AllData\maze-128-128-10-4-6-label1.png
# maze-128-128-10 5 5 edgelists/new_format/nathan_AllData\maze-128-128-10-5-5-label1.png
# maze-128-128-10 5 6 edgelists/new_format/nathan_AllData\maze-128-128-10-5-6-label1.png
# maze-128-128-10 6 5 edgelists/new_format/nathan_AllData\maze-128-128-10-6-5-label1.png
# maze-128-128-10 6 6 edgelists/new_format/nathan_AllData\maze-128-128-10-6-6-label4.png
# maze-128-128-10 7 5 edgelists/new_format/nathan_AllData\maze-128-128-10-7-5-label1.png
# maze-128-128-10 7 6 edgelists/new_format/nathan_AllData\maze-128-128-10-7-6-label4.png
# maze-128-128-10 8 5 edgelists/new_format/nathan_AllData\maze-128-128-10-8-5-label1.png
