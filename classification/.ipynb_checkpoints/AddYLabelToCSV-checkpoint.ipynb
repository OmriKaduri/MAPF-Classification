# %%
import pandas as pd

# %%
df = pd.read_csv('data/from-azure/kiva.csv')

# %%
features_cols = ['GridRows', 'GridColumns', 'NumOfAgents', 'NumOfObstacles', 'BranchingFactor', 'ObstacleDensity',
            'AvgDistanceToGoal', 'MaxDistanceToGoal', 'MinDistanceToGoal', 'AvgStartDistances', 'AvgGoalDistances',
            'PointsAtSPRatio']
runtime_cols = list(df.filter(like="Runtime"))
relev_cols = runtime_cols + features_cols + ['Y']

# %%
runtime_cols
# Out:
# ['A*+OD+ID Runtime',
#  'MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime',
#  'Basic-CBS/(A*/SIC)+ID Runtime',
#  'ICTS 3E +ID Runtime',
#  'EPEA*+ID Runtime']

# %%
Y = df[runtime_cols].idxmin(axis=1)
df['Y'] = Y

# %%
def runtime_to_success(col):
    splitted = col.split()
    splitted[-1] = "Success"
    return " ".join(splitted)

runtime_to_success("Y Runtime")
# Out:
# 'Y Success'

# %%
df['Y Success'] = df.apply(lambda x:x[runtime_to_success(x['Y'])], axis=1)

# %%
df['Y Runtime'] = df.apply(lambda x:x[x['Y']], axis=1)

# %%
df['Y Runtime']
# Out:
# 0         36.1523
# 1          0.2233
# 2          0.1780
# 3          9.4175
# 4          1.3981
# 5          0.2648
# 6          0.1520
# 7          0.9886
# 8         19.7434
# 9          9.3865
# 10      1082.1355
# 11         9.4452
# 12        18.2235
# 13        16.4274
# 14       107.4911
# 15         9.7791
# 16        99.0262
# 17        36.9424
# 18         9.1724
# 19        64.6264
# 20         3.0480
# 21      1086.9949
# 22      4947.1774
# 23     12234.1486
# 24      1231.7391
# 25       486.3215
# 26        36.0003
# 27       107.8146
# 28       341.2155
# 29        44.0977
#          ...
# 42    300003.3809
# 43       451.5142
# 44    300001.8174
# 45    300001.9858
# 46    300006.2895
# 47       620.6278
# 48    300010.6969
# 49    205326.4450
# 50    300007.5871
# 51    300007.1289
# 52    300004.9259
# 53    300016.3989
# 54    300004.3987
# 55    300001.2882
# 56    300004.0257
# 57    300003.2899
# 58    300008.4235
# 59    300002.1119
# 60    300001.7965
# 61    300001.1247
# 62    300009.5829
# 63    300007.8875
# 64    300013.9464
# 65    300007.4366
# 66    300009.5808
# 67    300011.3407
# 68    300003.0129
# 69    300007.5087
# 70    300003.7773
# 71    300015.3734
# Name: Y Runtime, Length: 72, dtype: float64

# %%
df['Y'].value_counts()
# Out:
# Basic-CBS/(A*/SIC)+ID Runtime                                                    24
# MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime    23
# ICTS 3E +ID Runtime                                                              12
# EPEA*+ID Runtime                                                                 10
# A*+OD+ID Runtime                                                                  3
# Name: Y, dtype: int64

# %% [markdown]
# ## Add Sparsity feature

# %%
df['GridSize'] = df['GridRows'] * df['GridColumns']

# %%
df['Sparsity'] = df.apply(lambda x: x['NumOfAgents']/(x['GridSize']-x['NumOfObstacles']),axis=1)

# %%
features_cols.append('GridSize')
features_cols.append('Sparsity')

# %%
features_cols.append('Y')
df[features_cols].corr()
# Out:
#                    GridRows  GridColumns   NumOfAgents  NumOfObstacles  \
# GridRows                NaN          NaN           NaN             NaN
# GridColumns             NaN          NaN           NaN             NaN
# NumOfAgents             NaN          NaN  1.000000e+00             NaN
# NumOfObstacles          NaN          NaN           NaN             NaN
# BranchingFactor         NaN          NaN  3.166183e-01             NaN
# ObstacleDensity         NaN          NaN -6.773119e-16             NaN
# AvgDistanceToGoal       NaN          NaN  1.499232e-01             NaN
# MaxDistanceToGoal       NaN          NaN  4.811157e-01             NaN
# MinDistanceToGoal       NaN          NaN -4.176027e-01             NaN
# AvgStartDistances       NaN          NaN  6.526064e-01             NaN
# AvgGoalDistances        NaN          NaN  6.980675e-01             NaN
# PointsAtSPRatio         NaN          NaN  9.391103e-01             NaN
# GridSize                NaN          NaN           NaN             NaN
# Sparsity                NaN          NaN  1.000000e+00             NaN
#
#                    BranchingFactor  ObstacleDensity  AvgDistanceToGoal  \
# GridRows                       NaN              NaN                NaN
# GridColumns                    NaN              NaN                NaN
# NumOfAgents           3.166183e-01    -6.773119e-16       1.499232e-01
# NumOfObstacles                 NaN              NaN                NaN
# BranchingFactor       1.000000e+00     2.453595e-16       5.384168e-02
# ObstacleDensity       2.453595e-16     1.000000e+00      -2.252270e-16
# AvgDistanceToGoal     5.384168e-02    -2.252270e-16       1.000000e+00
# MaxDistanceToGoal     1.846006e-01     6.440290e-16       5.148223e-01
# MinDistanceToGoal    -9.727106e-02     0.000000e+00       2.053689e-01
# AvgStartDistances     7.674998e-02     1.817104e-15       2.734999e-01
# AvgGoalDistances      1.071488e-01    -1.984054e-16       1.969052e-01
# PointsAtSPRatio       1.684845e-01     1.886224e-16       3.116087e-01
# GridSize                       NaN              NaN                NaN
# Sparsity              3.166183e-01     6.593109e-16       1.499232e-01
#
#                    MaxDistanceToGoal  MinDistanceToGoal  AvgStartDistances  \
# GridRows                         NaN                NaN                NaN
# GridColumns                      NaN                NaN                NaN
# NumOfAgents             4.811157e-01          -0.417603       6.526064e-01
# NumOfObstacles                   NaN                NaN                NaN
# BranchingFactor         1.846006e-01          -0.097271       7.674998e-02
# ObstacleDensity         6.440290e-16           0.000000       1.817104e-15
# AvgDistanceToGoal       5.148223e-01           0.205369       2.734999e-01
# MaxDistanceToGoal       1.000000e+00          -0.096289       6.382731e-01
# MinDistanceToGoal      -9.628908e-02           1.000000      -2.515828e-01
# AvgStartDistances       6.382731e-01          -0.251583       1.000000e+00
# AvgGoalDistances        4.535112e-01          -0.314711       6.505115e-01
# PointsAtSPRatio         6.004857e-01          -0.406111       7.474735e-01
# GridSize                         NaN                NaN                NaN
# Sparsity                4.811157e-01          -0.417603       6.526064e-01
#
#                    AvgGoalDistances  PointsAtSPRatio  GridSize      Sparsity
# GridRows                        NaN              NaN       NaN           NaN
# GridColumns                     NaN              NaN       NaN           NaN
# NumOfAgents            6.980675e-01     9.391103e-01       NaN  1.000000e+00
# NumOfObstacles                  NaN              NaN       NaN           NaN
# BranchingFactor        1.071488e-01     1.684845e-01       NaN  3.166183e-01
# ObstacleDensity       -1.984054e-16     1.886224e-16       NaN  6.593109e-16
# AvgDistanceToGoal      1.969052e-01     3.116087e-01       NaN  1.499232e-01
# MaxDistanceToGoal      4.535112e-01     6.004857e-01       NaN  4.811157e-01
# MinDistanceToGoal     -3.147113e-01    -4.061105e-01       NaN -4.176027e-01
# AvgStartDistances      6.505115e-01     7.474735e-01       NaN  6.526064e-01
# AvgGoalDistances       1.000000e+00     7.506458e-01       NaN  6.980675e-01
# PointsAtSPRatio        7.506458e-01     1.000000e+00       NaN  9.391103e-01
# GridSize                        NaN              NaN       NaN           NaN
# Sparsity               6.980675e-01     9.391103e-01       NaN  1.000000e+00

# %% [markdown]
# ## Save labelled data to file

# %%
#df.to_csv("data/from-azure/kiva-labelled.csv")
