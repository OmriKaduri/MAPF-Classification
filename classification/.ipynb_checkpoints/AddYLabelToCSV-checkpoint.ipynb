# %%
import pandas as pd

# %% [markdown]
# ## Load the unlabelled dataset ##

# %%
df = pd.read_csv('data/from-vpn/AllData.csv')
df.index
# Out:
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (145,148,149,150) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# RangeIndex(start=0, stop=96234, step=1)

# %%
features_cols = ['GridRows', 'GridColumns', 'NumOfAgents', 'NumOfObstacles', 'BranchingFactor', 'ObstacleDensity',
            'AvgDistanceToGoal', 'MaxDistanceToGoal', 'MinDistanceToGoal', 'AvgStartDistances', 'AvgGoalDistances',
            'PointsAtSPRatio']
runtime_cols = list(df.filter(like="Runtime"))
relev_cols = runtime_cols + features_cols + ['Y']

# %%
runtime_cols
# Out:
# ['A*+OD+ID Runtime',
#  'MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime',
#  'Basic-CBS/(A*/SIC)+ID Runtime',
#  'ICTS 3E +ID Runtime',
#  'EPEA*+ID Runtime',
#  'CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime',
#  'SAT Runtime']

# %% [markdown]
# ## Create Y Column with argmin on runtime_cols ##

# %%
df[runtime_cols]
# Out:
#        A*+OD+ID Runtime  \
# 0               75.7295
# 1                5.2334
# 2                6.0557
# 3               10.5929
# 4               13.5519
# 5               26.4102
# 6               42.9793
# 7               49.5234
# 8               66.7485
# 9               79.8633
# 10              92.2065
# 11             110.3553
# 12             116.1576
# 13             133.7242
# 14             164.4717
# 15             166.3648
# 16             198.1116
# 17             231.2501
# 18             244.9592
# 19             265.0393
# 20             287.4486
# 21             281.3843
# 22             299.5235
# 23             342.4698
# 24             364.6119
# 25             616.6964
# 26             634.6774
# 27             679.2138
# 28             735.4367
# 29             758.2443
# ...                 ...
# 96204       300000.0000
# 96205       300000.0000
# 96206       300000.0000
# 96207       300000.0000
# 96208       300000.0000
# 96209       300000.0000
# 96210       300000.0000
# 96211       300000.0000
# 96212       300000.0000
# 96213       300000.0000
# 96214       300000.0000
# 96215       300000.0000
# 96216       300000.0000
# 96217       300000.0000
# 96218       300000.0000
# 96219       300000.0000
# 96220       300000.0000
# 96221       300000.0000
# 96222       300000.0000
# 96223       300000.0000
# 96224       300000.0000
# 96225       300000.0000
# 96226       300000.0000
# 96227       300000.0000
# 96228       300000.0000
# 96229       300000.0000
# 96230       300000.0000
# 96231       300000.0000
# 96232       300000.0000
# 96233       300000.0000
#
#        MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime  \
# 0                                                48.8441
# 1                                                 0.1354
# 2                                                 0.2008
# 3                                                 0.3776
# 4                                                 0.4698
# 5                                                 0.7052
# 6                                                 1.2086
# 7                                                 1.1268
# 8                                                 1.3442
# 9                                                 1.5595
# 10                                                8.3311
# 11                                                2.2336
# 12                                                2.3610
# 13                                                2.3240
# 14                                                2.5441
# 15                                                2.7872
# 16                                                3.3687
# 17                                                3.1579
# 18                                              112.2840
# 19                                               60.5332
# 20                                               58.5799
# 21                                               68.9627
# 22                                               57.6565
# 23                                               58.7836
# 24                                               59.7228
# 25                                               59.7946
# 26                                               63.4056
# 27                                               60.5569
# 28                                               62.4887
# 29                                               65.4556
# ...                                                  ...
# 96204                                        300000.0000
# 96205                                        300000.0000
# 96206                                        300000.0000
# 96207                                        300000.0000
# 96208                                        300000.0000
# 96209                                        300000.0000
# 96210                                        300000.0000
# 96211                                        300000.0000
# 96212                                        300000.0000
# 96213                                        300000.0000
# 96214                                        300000.0000
# 96215                                        300000.0000
# 96216                                        300000.0000
# 96217                                        300000.0000
# 96218                                        300000.0000
# 96219                                        300000.0000
# 96220                                        300000.0000
# 96221                                        300000.0000
# 96222                                        300000.0000
# 96223                                        300000.0000
# 96224                                        300000.0000
# 96225                                        300000.0000
# 96226                                        300000.0000
# 96227                                        300000.0000
# 96228                                        300000.0000
# 96229                                        300000.0000
# 96230                                        300000.0000
# 96231                                        300000.0000
# 96232                                        300000.0000
# 96233                                        300000.0000
#
#        Basic-CBS/(A*/SIC)+ID Runtime  ICTS 3E +ID Runtime  EPEA*+ID Runtime  \
# 0                             2.4742               2.6185            1.3487
# 1                             1.9447               1.8911            1.8622
# 2                             6.1211               5.6710            5.5621
# 3                            10.5565              10.3796           10.5652
# 4                            13.5414              13.6807           13.7112
# 5                            27.8298              27.6709           28.6532
# 6                            44.5217              36.8707           38.4553
# 7                            50.2001              46.4985           46.2204
# 8                            70.1400              69.1274           69.0126
# 9                            79.8691              80.6823           80.1122
# 10                          100.7670             113.6307           92.5861
# 11                          109.4452             110.2762          105.2277
# 12                          114.7616             115.5956          112.6600
# 13                          129.3823             127.5185          134.7282
# 14                          141.0809             145.1771          154.8004
# 15                          167.4471             170.3246          179.3585
# 16                          198.1992             188.7830          234.2242
# 17                          226.2403             229.8758          218.0892
# 18                          249.5260             249.6322          237.1522
# 19                          273.2067             270.0820          287.5158
# 20                          281.4845             282.4937          268.3211
# 21                          287.6732             294.4926          288.8280
# 22                          303.5124             316.8374          323.3054
# 23                          339.5907             337.7164          336.3603
# 24                          355.4708             373.0203          367.1827
# 25                          590.4471             568.0629          567.4156
# 26                          644.2028             640.8548          633.7180
# 27                          681.9451             672.2157          663.7661
# 28                          719.5725             714.2509          716.0454
# 29                          759.8948             765.1634          744.8837
# ...                              ...                  ...               ...
# 96204                    300000.0000          300000.0000       300000.0000
# 96205                    300000.0000          300000.0000       300000.0000
# 96206                    300000.0000          300000.0000       300000.0000
# 96207                    300000.0000          300000.0000       300000.0000
# 96208                    300000.0000          300000.0000       300000.0000
# 96209                    300000.0000          300000.0000       300000.0000
# 96210                    300000.0000          300000.0000       300000.0000
# 96211                    300000.0000          300000.0000       300000.0000
# 96212                    300000.0000          300000.0000       300000.0000
# 96213                    300000.0000          300000.0000       300000.0000
# 96214                    300000.0000          300000.0000       300000.0000
# 96215                    300000.0000          300000.0000       300000.0000
# 96216                    300000.0000          300000.0000       300000.0000
# 96217                    300000.0000          300000.0000       300000.0000
# 96218                    300000.0000          300000.0000       300000.0000
# 96219                    300000.0000          300000.0000       300000.0000
# 96220                    300000.0000          300000.0000       300000.0000
# 96221                    300000.0000          300000.0000       300000.0000
# 96222                    300000.0000          300000.0000       300000.0000
# 96223                    300000.0000          300000.0000       300000.0000
# 96224                    300000.0000          300000.0000       300000.0000
# 96225                    300000.0000          300000.0000       300000.0000
# 96226                    300000.0000          300000.0000       300000.0000
# 96227                    300000.0000          300000.0000       300000.0000
# 96228                    300000.0000          300000.0000       300000.0000
# 96229                    300000.0000          300000.0000       300000.0000
# 96230                    300000.0000          300000.0000       300000.0000
# 96231                    300000.0000          300000.0000       300000.0000
# 96232                    300000.0000          300000.0000       300000.0000
# 96233                    300000.0000          300000.0000       300000.0000
#
#        CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime  \
# 0                                                54.4875
# 1                                                 0.1684
# 2                                                 0.2337
# 3                                                 1.5976
# 4                                                 0.5191
# 5                                                 0.7430
# 6                                                 0.9812
# 7                                                 1.1771
# 8                                                 1.4591
# 9                                                 1.7848
# 10                                                2.1272
# 11                                                2.2416
# 12                                                2.3111
# 13                                                2.6585
# 14                                                3.5572
# 15                                                3.0262
# 16                                                3.3097
# 17                                                3.7880
# 18                                               71.1741
# 19                                                8.2490
# 20                                                8.6302
# 21                                                8.2906
# 22                                                8.3196
# 23                                                8.4865
# 24                                               10.1915
# 25                                                9.6838
# 26                                               11.9596
# 27                                               10.6592
# 28                                               10.6086
# 29                                               11.3034
# ...                                                  ...
# 96204                                        300000.0000
# 96205                                        300000.0000
# 96206                                        300000.0000
# 96207                                        300000.0000
# 96208                                        300000.0000
# 96209                                        300000.0000
# 96210                                        300000.0000
# 96211                                        300000.0000
# 96212                                        300000.0000
# 96213                                        300000.0000
# 96214                                        300000.0000
# 96215                                        300000.0000
# 96216                                        300000.0000
# 96217                                        300000.0000
# 96218                                        300000.0000
# 96219                                        300000.0000
# 96220                                        300000.0000
# 96221                                        300000.0000
# 96222                                        300000.0000
# 96223                                        300000.0000
# 96224                                        300000.0000
# 96225                                        300000.0000
# 96226                                        300000.0000
# 96227                                        300000.0000
# 96228                                        300000.0000
# 96229                                        300000.0000
# 96230                                        300000.0000
# 96231                                        300000.0000
# 96232                                        300000.0000
# 96233                                        300000.0000
#
#        SAT Runtime
# 0      300000.0000
# 1      300000.0000
# 2      300000.0000
# 3      300000.0000
# 4      300000.0000
# 5      300000.0000
# 6      300000.0000
# 7      300000.0000
# 8      300000.0000
# 9      300000.0000
# 10     300000.0000
# 11     300000.0000
# 12     300000.0000
# 13     300000.0000
# 14     300000.0000
# 15     300000.0000
# 16     300000.0000
# 17     300000.0000
# 18     300000.0000
# 19     300000.0000
# 20     300000.0000
# 21     300000.0000
# 22     300000.0000
# 23     300000.0000
# 24     300000.0000
# 25     300000.0000
# 26     300000.0000
# 27     300000.0000
# 28     300000.0000
# 29     300000.0000
# ...            ...
# 96204   62350.2399
# 96205   35111.1074
# 96206   45811.8014
# 96207   41581.6734
# 96208   40062.0892
# 96209   57289.0839
# 96210   43914.8064
# 96211   45141.0995
# 96212   40015.1539
# 96213   76394.7941
# 96214   51217.2691
# 96215   45807.2475
# 96216   47007.9650
# 96217   62920.0011
# 96218   86315.4320
# 96219   73282.3974
# 96220   45775.2599
# 96221   74030.3396
# 96222   56155.5891
# 96223   72367.0353
# 96224   54411.1550
# 96225   77815.9752
# 96226   90387.8064
# 96227   45346.9010
# 96228   55153.0779
# 96229   66561.1601
# 96230   58679.8275
# 96231   62340.3722
# 96232   94575.6878
# 96233   61673.1425
#
# [96234 rows x 7 columns]

# %%
Y = df[runtime_cols].idxmin(axis=1)
df['Y'] = Y

# %%
df.iloc[400][runtime_cols], df.iloc[400]['Y'] # SANITY CHECK
# Out:
# (A*+OD+ID Runtime                                                                                                                                  26712.6
#  MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime                                                                      300000
#  Basic-CBS/(A*/SIC)+ID Runtime                                                                                                                     27318.6
#  ICTS 3E +ID Runtime                                                                                                                               30960.3
#  EPEA*+ID Runtime                                                                                                                                  26978.1
#  CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime    3496.65
#  SAT Runtime                                                                                                                                        300000
#  Name: 400, dtype: object,
#  'CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime')

# %%
def runtime_to_success(col):
    splitted = col.split()
    splitted[-1] = "Success"
    return " ".join(splitted)

runtime_to_success("Y Runtime")
# Out:
# 'Y Success'

# %%
df['Y Success'] = df.apply(lambda x:x[runtime_to_success(x['Y'])], axis=1)

# %%
df['Y Runtime'] = df.apply(lambda x:x[x['Y']], axis=1)

# %%
# df[~df['GridName'].str.contains('warehouse')]['Y'].value_counts()
df['Y'].value_counts()
# Out:
# SAT Runtime                                                                                                                                       55008
# CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime    18922
# MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime                                                                     10492
# ICTS 3E +ID Runtime                                                                                                                                4549
# EPEA*+ID Runtime                                                                                                                                   4489
# A*+OD+ID Runtime                                                                                                                                   2421
# Basic-CBS/(A*/SIC)+ID Runtime                                                                                                                       353
# Name: Y, dtype: int64

# %% [markdown]
# ## Add Sparsity feature

# %%
df['GridSize'] = df['GridRows'] * df['GridColumns']

# %%
df['Sparsity'] = df.apply(lambda x: x['NumOfAgents']/(x['GridSize']-x['NumOfObstacles']),axis=1)

# %%
len(df)
# Out:
# 96234

# %%
features_cols.append('GridSize')
features_cols.append('Sparsity')

# %%
features_cols.append('Y')
features_cols.append('Y Runtime')
features_cols.append('Y Success')

# %% [markdown]
# ## Drop unused features ##

# %%
df = df[list(set(features_cols))]

# %% [markdown]
# ## Save labelled data to file

# %%
df.to_csv("data/from-vpn/AllData-labelled.csv", index=False)

# %% [markdown]
# ## Adding ranking (in order to train LTR models) ##

# %% [markdown]
# # In order to add 'bridges' feature use CreateGridFromMapFile notebook
