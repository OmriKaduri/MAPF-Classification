# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="ticks", color_codes=True)
# %matplotlib inline

# %% [markdown]
# ## Import the labelled dataset ##

# %%
df = pd.read_csv('data/from-vpn/AllData-labelled.csv', low_memory=False)

# df = pd.read_csv('data/from-azure/nathan_AllData-labelled.csv')
# df = df[df.ObstacleDensity > 0.1]

# %%
diffs = df[df.GridName=='Berlin_1_256'].NumOfAgents.diff() < 1
prev_index=0
scen_ids = []
curr_id=1
for index in diffs[diffs==False].index[1:]:
#     print(curr_id)
#     print(len([curr_id]*(index-prev_index)))
    scen_ids.extend([curr_id]*(index-prev_index))
    prev_index = index
    curr_id+=1
    
# print(len([curr_id]*(len(df)-index)))
scen_ids.extend([curr_id]*(len(df)-prev_index))
    
# diffs[x`xinstance_keys[0]:instance_keys[1]-1]
# df.iloc[102]
# first_instance_keys[1]
len(scen_ids), len(df)
df['scen_id'] = scen_ids

# %%
# GridRows	GridColumns	NumOfAgents	NumOfObstacles	BranchingFactor	ObstacleDensity	AvgDistanceToGoal	MaxDistanceToGoal	MinDistanceToGoal	AvgStartDistances	AvgGoalDistances	PointsAtSPRatio, Sparsity


features_cols = ['GridRows','GridColumns', 'NumOfAgents','NumOfObstacles',
            'BranchingFactor', 'ObstacleDensity', 'AvgDistanceToGoal', 'MaxDistanceToGoal', 'MinDistanceToGoal', 'AvgStartDistances', 'AvgGoalDistances',
              'PointsAtSPRatio', 'Sparsity']
#                  'bridges']
# features_cols = [ 'NumOfAgents', 'ObstacleDensity', 'PointsAtSPRatio', 'NumOfObstacles']

# %%
#Currently, not all solvers solved warehouse problems, thus we won't take them into account
df = df[~df.GridName.str.contains('warehouse')]

# %% [markdown]
# ## Replace every row with runtime greater then 300000 (5 minutes) to be 300000 - removing computation errors (somehow it kept running more than 5 minutes) ##

# %%
# runtime_cols = list(df.filter(like="Runtime"))
def runtime_to_success(col):
    splitted = col.split()
    splitted[-1] = "Success"
    return " ".join(splitted)

max_runtime = 300000

runtime_cols = list(df.filter(like="Runtime"))
success_cols = list(df.filter(regex="Success$"))

for runtime_col in runtime_cols:
    df[runtime_col] = df[runtime_col].where(df[runtime_col] < max_runtime, max_runtime)
    success_col = runtime_to_success(runtime_col)
    df[success_col] = df.apply(lambda x: df[runtime_col] < max_runtime, 0)
# for runtimsuccess_col in success_cols:
#     df[success_col] = df.apply(lambda x: df[runtime_col] < max_runtime, 0)

# %% [markdown]
# ## Add map type to each row ##

# %%
def map_type(x):
    cities = ['Berlin','Boston','Paris']
    games = ['brc','den','ht_','lak','lt_','orz','ost','woundedcoast']
    maze = ['maze']
    if any(city in x for city in cities):
        return 'city'
    elif any(game in x for game in games):
        return 'game'
    elif 'maze' in x:
        return 'maze'
    elif 'room' in x:
        return 'room'
    elif 'random' in x:
        return 'random'
    elif 'empty' in x:
        return 'empty'
    else:
        print("OH SHIT!",x)
        return 'other'
    
df['maptype'] = df.apply(lambda x: map_type(x['GridName']),axis=1)
df['maptype'].value_counts()
# features_cols.append('maptype')
# Out:
# game      25509
# random    16209
# city      15519
# empty     14766
# room       4417
# maze       3914
# Name: maptype, dtype: int64

# %%
# runtime_cols = list(df.filter(like="Runtime"))

runtime_cols
runtime_cols.remove('Basic-CBS/(A*/SIC)+ID Runtime')

# %%
solved_df = df[df['Y Runtime'] < max_runtime] # IGNORING ALL UNSOLVED PROBLEMS

# solved_df = df

# %%
count_df = df['Y'].value_counts().reset_index()
count_df['BestPercentage'] = count_df.apply(lambda row: row['Y']/len(df), axis=1)
count_df
# Out:
#                                                index      Y  BestPercentage
# 0                                        SAT Runtime  39274        0.488884
# 1  CBS/(A*/SIC) + BP + PC without smart tie break...  18922        0.235542
# 2  MA-CBS-Global-10/(EPEA*/SIC) choosing the firs...  10492        0.130605
# 3                                ICTS 3E +ID Runtime   4549        0.056626
# 4                                   EPEA*+ID Runtime   4489        0.055879
# 5                                   A*+OD+ID Runtime   2255        0.028070
# 6                      Basic-CBS/(A*/SIC)+ID Runtime    353        0.004394

# %%
count_df = solved_df[solved_df['Y Runtime'] < max_runtime]['Y'].value_counts().reset_index()
count_df['BestPercentage'] = count_df.apply(lambda row: row['Y']/len(solved_df), axis=1)
count_df
# Out:
#                                                index      Y  BestPercentage
# 0                                        SAT Runtime  39259        0.500868
# 1  CBS/(A*/SIC) + BP + PC without smart tie break...  18922        0.241407
# 2  MA-CBS-Global-10/(EPEA*/SIC) choosing the firs...  10394        0.132607
# 3                                ICTS 3E +ID Runtime   4549        0.058036
# 4                                   EPEA*+ID Runtime   4489        0.057271
# 5                                   A*+OD+ID Runtime    421        0.005371
# 6                      Basic-CBS/(A*/SIC)+ID Runtime    348        0.004440

# %%
print("Choosing the best alogirthm each time accuracy:", solved_df['Y'].value_counts()[0] / len(solved_df))
# Out:
# Choosing the best alogirthm each time accuracy: 0.5008675461202827

# %% [markdown]
# ## Use pandas-profiling for some basic exploration. TAKES TIMES TO RUN ##

# %%
# import pandas_profiling

# pandas_profiling.ProfileReport(solved_df[features_cols + runtime_cols + ["Y"]])

# %%
fig, axes = plt.subplots(3, 2, sharey=True, sharex=True, figsize=(15,7))
index =0
for runtime_col in runtime_cols:
    if 'P Runtime' in runtime_col or 'Y Runtime' in runtime_col:
        continue
    print(runtime_col)
    solved_df[runtime_col].hist(ax=axes[index%3][index%2])
    axes[index%3][index%2].set_title(runtime_col)
    index += 1

plt.tight_layout()
# Out:
# A*+OD+ID Runtime
# MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime
# ICTS 3E +ID Runtime
# EPEA*+ID Runtime
# CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime
# SAT Runtime

# %%
# features_cols.remove('NumOfObstacles')
# features_cols.remove('MaxDistanceToGoal')
# features_cols.remove('AvgStartDistances')

# %% [markdown]
# ## We can see that MA-CBS Fail much more then the others (reach the 300000 timeout)

# %%
alg_runtime_cols = runtime_cols.copy()
if 'P Runtime' in alg_runtime_cols:
    alg_runtime_cols.remove('P Runtime')
results_df = solved_df[alg_runtime_cols + features_cols].copy()
# results_df.to_csv("data/from-azure/AllData-results.csv", index=False)

# %% [markdown]
# ## Let's see some baselines for classification models ##

# %% [markdown]
# ## Balancing the dataset

# %%
# g = solved_df.groupby('Y')
# balanced_df = g.apply(lambda x: x.sample(g.size().min()).reset_index(drop=True))

# %%
import xgboost as xgb

from sklearn.model_selection import train_test_split, GroupShuffleSplit
# solved_df = solved_df[solved_df.maptype=='game']

groups = solved_df['InstanceId'] #len of scenarios
gkf = GroupShuffleSplit(n_splits=2, test_size=0.2)
train, test = next(gkf.split(solved_df,solved_df['Y'], groups=groups, ))
X_train, X_test, y_train, y_test = solved_df.iloc[train], solved_df.iloc[test], solved_df['Y'].iloc[train],solved_df['Y'].iloc[test]


# X_train, X_test, y_train, y_test = train_test_split(solved_df, solved_df['Y'],
#                                                     test_size=0.25,
# #                                                    stratify=solved_df['GridName'].values
#                                                    )

# X_train = pd.read_csv('data/from-vpn/splitted/X_train.csv')
# X_test = pd.read_csv('data/from-vpn/splitted/X_test.csv')
# train_dummies = pd.get_dummies(X_train['GridName'])
# X_train = pd.concat([X_train,train_dummies], axis=1)
# test_dummies = pd.get_dummies(X_test['GridName'])
# X_test = pd.concat([X_test,test_dummies], axis=1)

# features_cols.extend(train_dummies.columns.values)

y_train = X_train['Y']
y_test = X_test['Y']
# X_train = pd.read_csv('data/from-azure/splitted/train_features.csv')
# y_train = pd.read_csv('data/from-azure/splitted/train_labels.csv')
# X_test = pd.read_csv('data/from-azure/splitted/test_features.csv')
# y_test = pd.read_csv('data/from-azure/splitted/test_labels.csv')
len(X_train),len(X_test )
# Out:
# (63548, 14834)

# %%
X_train.groupby('InstanceId').size(), X_test.groupby('InstanceId').size()
# Out:
# (InstanceId
#  2     3016
#  3     3020
#  4     4214
#  5     2901
#  6     2912
#  7     3261
#  9     3028
#  10    3864
#  11    2993
#  12    3110
#  15    3103
#  16    3036
#  17    2861
#  18    2901
#  20    4442
#  21    3050
#  22    3108
#  23    3025
#  24    2753
#  25    2950
#  dtype: int64, InstanceId
#  1     2863
#  8     3065
#  13    2879
#  14    3011
#  19    3016
#  dtype: int64)

# %%
def plot_cv_indices(cv, X, y, group, ax, n_splits, lw=10):
    """Create a sample plot for indices of a cross-validation object."""

    # Generate the training/testing visualizations for each CV split
    for ii, (tr, tt) in enumerate(cv.split(X=X, y=y, groups=group)):
        # Fill in indices with the training/test groups
        indices = np.array([np.nan] * len(X))
        indices[tt] = 1
        indices[tr] = 0

        # Visualize the results
        ax.scatter(range(len(indices)), [ii + .5] * len(indices),
                   c=indices, marker='_', lw=lw, cmap=cmap_cv,
                   vmin=-.2, vmax=1.2)
        print(cmap_cv)
    # Plot the data classes and groups at the end
    ax.scatter(range(len(X)), [ii + 1.5] * len(X),
               c=y, marker='_', lw=lw, cmap=cmap_data)

    ax.scatter(range(len(X)), [ii + 2.5] * len(X),
               c=group, marker='_', lw=lw, cmap=cmap_data)

    # Formatting
    yticklabels = list(range(n_splits)) + ['class', 'group']
    ax.set(yticks=np.arange(n_splits+2) + .5, yticklabels=yticklabels,
           xlabel='Sample index', ylabel="CV iteration",
           ylim=[n_splits+2.2, -.2], xlim=[0, len(indices)])
    ax.set_title('{}'.format(type(cv).__name__), fontsize=15)
    return ax

# %%
def int_from_label(label):
    return {
        'EPEA*+ID Runtime': 0,
        'MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime':1,
        'ICTS 3E +ID Runtime':2,
        'A*+OD+ID Runtime':3,
        'Basic-CBS/(A*/SIC)+ID Runtime':4
        'SAT Runtime':5
    }[x]

# %%
fig, ax = plt.subplots()

partttt = solved_df[solved_df['InstanceId'].isin([2,3,4,5,6,9,11 ])]
plot_cv_indices(gkf, solved_df, [int_from_label(y) for y in solved_df['Y']], solved_df['InstanceId'], ax, 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-e1184d5937ec> in <module>
#       2
#       3 partttt = solved_df[solved_df['InstanceId'].isin([2,3,4,5,6,9,11 ])]
# ----> 4 plot_cv_indices(gkf, solved_df, [int_from_label(y) for y in solved_df['Y']], solved_df['InstanceId'], ax, 2)
#
# <ipython-input-33-e1184d5937ec> in <listcomp>(.0)
#       2
#       3 partttt = solved_df[solved_df['InstanceId'].isin([2,3,4,5,6,9,11 ])]
# ----> 4 plot_cv_indices(gkf, solved_df, [int_from_label(y) for y in solved_df['Y']], solved_df['InstanceId'], ax, 2)
#
# NameError: name 'int_from_label' is not defined

# %%
# g = X_train.groupby('Y')
# balanced_df = g.apply(lambda x: x.sample(g.size().min()).reset_index(drop=True))

# X_train, X_test, y_train, y_test = train_test_split(balanced_df, balanced_df['Y'], test_size=0.25)

# %%
def coverage_score(df, preds, max_runtime=300000):
    tmp_df = df.copy()
    tmp_df['CurrP'] = preds
    tmp_df['CurrP-Runtime'] = tmp_df.apply(lambda x: int(x[x['CurrP']]), axis=1)
    solved = len(tmp_df[tmp_df['CurrP-Runtime'] < max_runtime])
    return solved/len(tmp_df)
#     solved = 0
#     for pred, (index, row) in zip(preds,df.iterrows()):
#         if(row[pred] < max_runtime):
#               solved += 1
#     return solved/len(df)

# %%
def cumsum_score(df, preds):
    tmp_df = df.copy()
    tmp_df['CurrP'] = preds
    tmp_df['CurrP-Runtime'] = tmp_df.apply(lambda x: int(x[x['CurrP']]), axis=1)
    cumsum = tmp_df['CurrP-Runtime'].sum()
#     cumsum = 0
#     for pred, (index, row) in zip(preds,df.iterrows()):
#         cumsum += row[pred]
    return cumsum/((60*(10**3)))

# %%
conversions = {
        0 : 'EPEA*+ID Runtime',
        1 : 'MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime',
        2 : 'ICTS 3E +ID Runtime',
        3 : 'A*+OD+ID Runtime',
        4 : 'Basic-CBS/(A*/SIC)+ID Runtime',
        5 : 'CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime',
        6 : 'SAT Runtime' 
}

import numpy as np
from sklearn.metrics import accuracy_score

random_preds = [conversions[x] for x in np.random.randint(0, 6, size=(len(X_test)))]
random_baseline = accuracy_score(y_test, random_preds)
print("Choosing Random accuracy:",random_baseline)
print("Choosing Random coverage:",coverage_score(X_test, random_preds))
print("Choosing Random cumsum:",cumsum_score(X_test, random_preds))
for key, conversion in conversions.items():
    preds =  [conversion] * len(X_test)
    print("Choosing", conversion,"accuracy:",accuracy_score(y_test,preds))
    print("Choosing", conversion,"coverage:",coverage_score(X_test, preds))
    print("Choosing", conversion,"cumsum:",cumsum_score(X_test, preds))
# Out:
# Choosing Random accuracy: 0.07360578008579814
# Choosing Random coverage: 0.3164935651388575
# Choosing Random cumsum: 61691.153216666666
# Choosing EPEA*+ID Runtime accuracy: 0.04233461277940844
# Choosing EPEA*+ID Runtime coverage: 0.3578685933619327
# Choosing EPEA*+ID Runtime cumsum: 58332.667466666666
# Choosing MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime accuracy: 0.11701286972228495
# Choosing MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime coverage: 0.231034093474825
# Choosing MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime cumsum: 68642.3358
# Choosing ICTS 3E +ID Runtime accuracy: 0.045834274102506206
# Choosing ICTS 3E +ID Runtime coverage: 0.35069993226461954
# Choosing ICTS 3E +ID Runtime cumsum: 59184.48986666666
# Choosing A*+OD+ID Runtime accuracy: 0.007394445698803342
# Choosing A*+OD+ID Runtime coverage: 0.33715285617520885
# Choosing A*+OD+ID Runtime cumsum: 60308.791783333334
# Choosing Basic-CBS/(A*/SIC)+ID Runtime accuracy: 0.0018627229622939715
# Choosing Basic-CBS/(A*/SIC)+ID Runtime coverage: 0.2699819372318808
# Choosing Basic-CBS/(A*/SIC)+ID Runtime cumsum: 65766.47695
# Choosing CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime accuracy: 0.2258410476405509
# Choosing CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime coverage: 0.36035222397832467
# Choosing CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime cumsum: 57483.71318333333
# Choosing SAT Runtime accuracy: 0.5597200270941521
# Choosing SAT Runtime coverage: 0.5636148114698577
# Choosing SAT Runtime cumsum: 44146.98933333333

# %%
grid_groups = X_train.groupby('GridName')
grid_results = {}
grid_solver = {}
for name, group in grid_groups.groups.items():
    grid_results[name] = 0
    for key, conversion in conversions.items():
#         print(name, conversion)
        conv_preds = [conversion]*len(group)
        cov_score = coverage_score(X_train.loc[group],conv_preds, )
        if cov_score > grid_results[name]:
            grid_results[name] = cov_score
            grid_solver[name] = conversion
            
def pick_best_solver_at_grid(row):
    return grid_solver[row['GridName']]

preds = X_test.apply(lambda x: pick_best_solver_at_grid(x), axis=1)
print("Choosing Best-at-grid accuracy:",accuracy_score(y_test,preds))

print("Choosing Best-at-grid coverage:",coverage_score(X_test, preds))
print("Choosing Best-at-grid cumsum:",cumsum_score(X_test,preds))
# Out:
# Choosing Best-at-grid accuracy: 0.4832919394897268
# Choosing Best-at-grid coverage: 0.5706141341160533
# Choosing Best-at-grid cumsum: 42404.94785

# %%
X_test['Random-P'] = random_preds

# %%
print("Choosing Optimal accuracy:",accuracy_score(y_test,X_test['Y']))

print("Choosing Optimal coverage:",coverage_score(X_test, X_test['Y']))
print("Choosing Optimal cumsum:",cumsum_score(X_test, X_test['Y']))
# Out:
# Choosing Optimal accuracy: 1.0
# Choosing Optimal coverage: 1.0
# Choosing Optimal cumsum: 6827.505433333334

# %%
X_train['GridName'].value_counts()
# Out:
# empty-48-48               5501
# Berlin_1_256              5170
# random-64-64-10           5065
# orz900d                   4935
# warehouse-20-40-10-2-2    4669
# Paris_1_256               4282
# warehouse-10-20-10-2-2    3560
# den520d                   3547
# empty-32-32               3439
# random-64-64-20           3130
# Boston_0_256              2805
# random-32-32-10           2782
# warehouse-20-40-10-2-1    2695
# ht_mansion_n              1976
# warehouse-10-20-10-2-1    1914
# random-32-32-20           1772
# w_woundedcoast            1740
# empty-16-16               1734
# room-64-64-16             1668
# ost003d                   1603
# ht_chantry                1561
# den312d                   1468
# lt_gallowstemplar_n       1412
# brc202d                   1247
# lak303d                   1149
# room-32-32-4               946
# empty-8-8                  919
# maze-128-128-10            810
# maze-32-32-4               787
# maze-32-32-2               755
# room-64-64-8               749
# maze-128-128-2             610
# Name: GridName, dtype: int64

# %%
alg_runtime_cols
# Out:
# ['A*+OD+ID Runtime',
#  'MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime',
#  'Basic-CBS/(A*/SIC)+ID Runtime',
#  'ICTS 3E +ID Runtime',
#  'EPEA*+ID Runtime',
#  'CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime',
#  'SAT Runtime',
#  'Y Runtime']

# %%
solved_df.groupby('GridName')['NumOfAgents'].max()
# Out:
# GridName
# Berlin_1_256               200
# Boston_0_256               108
# Paris_1_256                195
# brc202d                     51
# den312d                     59
# den520d                    145
# empty-16-16                 61
# empty-32-32                122
# empty-48-48                198
# empty-8-8                   30
# ht_chantry                  64
# ht_mansion_n                70
# lak303d                     41
# lt_gallowstemplar_n         45
# maze-128-128-10             28
# maze-128-128-2              22
# maze-32-32-2                28
# maze-32-32-4                30
# orz900d                   1280
# ost003d                     94
# random-32-32-10             87
# random-32-32-20             68
# random-64-64-10            171
# random-64-64-20            115
# room-32-32-4                33
# room-64-64-16               59
# room-64-64-8                39
# w_woundedcoast              82
# warehouse-10-20-10-2-1     123
# warehouse-10-20-10-2-2     217
# warehouse-20-40-10-2-1     201
# warehouse-20-40-10-2-2    1000
# Name: NumOfAgents, dtype: int64

# %%
import operator


def places_for(row, alg):
    results = {}
    sorted_results = {}
    for col in alg_runtime_cols:
        if 'Y Runtime' in col:
            continue
        results[col] = row[col]

    results = sorted(results.items(), key = operator.itemgetter(1))
    for index, (curr_alg, result) in enumerate(results):
        if curr_alg == alg:
            return index+1
    
    print("OH SHIT")

# %%
for alg in alg_runtime_cols:
    if 'Y Runtime' in alg:
        continue
    X_test[alg+'-results'] = X_test.apply(lambda x: places_for(x, alg), axis=1)
if 'P' in X_test:
    X_test['P Runtime-results'] = X_test.apply(lambda x: x[x['P']+'-results'], axis=1)
X_test['Random-results'] = X_test.apply(lambda x: x[x['Random-P']+'-results'], axis=1)
# Out:
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4379             try:
# -> 4380                 return libindex.get_value_box(s, key)
#    4381             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-d89bffc47c1d> in <module>
#       5 if 'P' in X_test:
#       6     X_test['P Runtime-results'] = X_test.apply(lambda x: x[x['P']+'-results'], axis=1)
# ----> 7 X_test['Random-results'] = X_test.apply(lambda x: x[x['Random-P']+'-results'], axis=1)
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\pandas\core\apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     255
#     256         # compute the result using the series generator
# --> 257         self.apply_series_generator()
#     258
#     259         # wrap results
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     284             try:
#     285                 for i, v in enumerate(series_gen):
# --> 286                     results[i] = self.f(v)
#     287                     keys.append(v.name)
#     288             except Exception as e:
#
# <ipython-input-31-d89bffc47c1d> in <lambda>(x)
#       5 if 'P' in X_test:
#       6     X_test['P Runtime-results'] = X_test.apply(lambda x: x[x['P']+'-results'], axis=1)
# ----> 7 X_test['Random-results'] = X_test.apply(lambda x: x[x['Random-P']+'-results'], axis=1)
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4386                     raise InvalidIndexError(key)
#    4387                 else:
# -> 4388                     raise e1
#    4389             except Exception:  # pragma: no cover
#    4390                 raise e1
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4372         try:
#    4373             return self._engine.get_value(s, k,
# -> 4374                                           tz=getattr(series.dtype, 'tz', None))
#    4375         except KeyError as e1:
#    4376             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Random-P', 'occurred at index 300')

# %%
train_sorted_algorithms = X_train[alg_runtime_cols].apply(np.sort, axis=1)
test_sorted_algorithms = X_test[alg_runtime_cols].apply(np.sort, axis=1)

# df['secondplace'] = YA = A.apply(np.sort, axis = 1) 
second_y_train = train_sorted_algorithms.apply(lambda x: x[1])
second_y_test = test_sorted_algorithms.apply(lambda x: x[1])

# %%
def folder_from_label(label):
    return {
        'EPEA*+ID Runtime': 'epea',
        'MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime': 'ma-cbs',
        'ICTS 3E +ID Runtime': 'icts',
        'A*+OD+ID Runtime': 'astar',
        'Basic-CBS/(A*/SIC)+ID Runtime': 'basic-cbs',
        'CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime': 'cbs-h',
        'Y Runtime': 'Oracle',
        'P Runtime': 'ML Model',
        'P-Reg Runtime': 'Regression Model',
        'P-Clf Runtime': 'Classification Model',
        'Random': 'Random'
    }[label]

# %%
def label_from_folder(label):
      return {
          'epea':'EPEA*+ID Runtime',
          'ma-cbs':'MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime',
          'icts':'ICTS 3E +ID Runtime',
          'astar':'A*+OD+ID Runtime',
          'basic-cbs':'Basic-CBS/(A*/SIC)+ID Runtime',
          'cbs-h':'CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime',
          'Oracle':'Y Runtime',
          'P Runtime':'ML Model',
          'Random':'Random'
      }[label]

# %%
fig, axes = plt.subplots(2, 3, sharey=True, sharex=True, figsize=(10,4))
index =0
for alg in runtime_cols:
    if 'Y Runtime' in alg or 'P Runtime' in alg:
        continue
#     X_test[(X_test.ObstacleDensity > 0.25) & (X_test.NumOfAgents > 50)][alg+'-results'].hist(ax=axes[index%3][index%2])
    X_test[alg+'-results'].hist(ax=axes[index%2][index%3])
    axes[index%2][index%3].set_title(folder_from_label(alg))
    print(alg, "avg place", X_test[alg+'-results'].mean(), X_test[alg+'-results'].std())

    index += 1
X_test['Random-results'].hist(ax=axes[index%2][index%3])
axes[index%2][index%3].set_title('Random')
print("Random avg place", X_test['Random-results'].mean(), X_test['Random-results'].std())
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-8d7d4df03417> in <module>
#       7 #     X_test[(X_test.ObstacleDensity > 0.25) & (X_test.NumOfAgents > 50)][alg+'-results'].hist(ax=axes[index%3][index%2])
#       8     X_test[alg+'-results'].hist(ax=axes[index%2][index%3])
# ----> 9     axes[index%2][index%3].set_title(folder_from_label(alg))
#      10     print(alg, "avg place", X_test[alg+'-results'].mean(), X_test[alg+'-results'].std())
#      11
#
# NameError: name 'folder_from_label' is not defined

# %%
fig = plt.figure(figsize=(13,6))
ax = fig.add_subplot(1, 1, 1)
index =0
X = [1,2,3,4,5,6]
vals = [0,0,0,0,0,0]
prevals = [0,0,0,0,0,0]
cols = []
for alg in runtime_cols:
    if 'Y Runtime' in alg:# or 'P Runtime' in alg:
        continue
    cols.append(alg)
    prevals = [a+b for a,b in zip(vals,prevals)]
    vals = X_test[alg+'-results'].value_counts().to_dict()
    vals = [v[1] for v in sorted(vals.items())]
    print(vals)
    if index==0:
        plt.bar(X, vals)
    else:
        plt.bar(X, vals, bottom=prevals)
    index += 1
plt.legend([folder_from_label(alg) for alg in cols])
# Out:
# [33, 1847, 2132, 1606, 1295, 1175]
# [2130, 998, 1647, 1471, 766, 1076]
# [35, 664, 965, 2423, 2395, 1606]
# [814, 1284, 1536, 1225, 2605, 624]
# [955, 1140, 1688, 1216, 950, 2139]
# [4121, 2155, 120, 147, 77, 1468]

# %% [markdown]
# ## Let's find all problems where ML Model fails ##

# %%
# X_test[(X_test['P Runtime-results']>2) & (X_test['P Runtime']>10000)][runtime_cols + ['Y'] + ['P']]

# %% [markdown]
# ## Load embeddings from CNN ##

# %%
train_embeddings = np.load('train_embeddings.txt.npy')
test_embeddings = np.load('test_embeddings.txt.npy')

# %%
embedding_cols = ['embeddding'+str(i) for i in range(0,64)]
train_embed_df = pd.DataFrame(train_embeddings, columns=embedding_cols)
test_embed_df = pd.DataFrame(test_embeddings, columns=embedding_cols)

# %%
X_train[embedding_cols] = train_embed_df
X_test[embedding_cols] = test_embed_df

# %% [markdown]
# ## XGBoost training

# %% [markdown]
# ## Regression models ##
# # Important to note that the regression data is only from the classification train data! #

# %%
# X_train[runtime_cols]/=1000
# X_test[runtime_cols]/=1000

# %%
def func(x):
#     return x
#     return np.log10(x)
    return np.log1p(x)
def inverse_func(x):
#     return x
#     return 10 ** x
    return np.expm1(x)

# %%
only_alg_runtime_cols = alg_runtime_cols.copy()
only_alg_runtime_cols.remove('Y Runtime')

# %%
train_samples_weight = X_train.apply(lambda x: np.std(x[only_alg_runtime_cols].values), axis=1)
# train_samples_weight = X_train.apply(lambda x: np.std(x[only_alg_runtime_cols].values), axis=1)
# train_samples_weight = X_train.apply(lambda x: np.std(x[only_alg_runtime_cols].values/1000), axis=1)

# %%
import seaborn as sns

sns.distplot(train_samples_weight)
# Out:
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from sklearn.model_selection import GroupKFold, LeavePGroupsOut, LeaveOneGroupOut,GroupShuffleSplit
train_groups = X_train['InstanceId'] #len of scenarios
# train_gkf = LeaveOneGroupOut()
train_gkf = GroupShuffleSplit(n_splits=5, test_size=0.3)

# %%
from sklearn.compose import TransformedTargetRegressor
from sklearn.model_selection import StratifiedKFold,cross_val_score, RandomizedSearchCV, GridSearchCV
from scipy import stats



xg_regs = []
regs_data = []
index = 0
for runtime_col in runtime_cols:
    if 'P Runtime' in runtime_col or 'Y Runtime' in runtime_col:
        continue
    print(index,":",runtime_col)
    index += 1
#     reg_X_train, reg_X_test, reg_y_train, reg_y_test = train_test_split(X_train[features_cols],
#                         X_train[runtime_col], test_size=0.3)
    regs_data.append([X_train[features_cols],X_test[features_cols], X_train[runtime_col], X_test[runtime_col]])
    xg_reg = xgb.XGBRegressor(objective ='reg:linear')#, colsample_bylevel= 0.5, colsample_bynode = 0.5)
    xg_reg_trans = TransformedTargetRegressor(regressor=xg_reg, func=func, inverse_func=inverse_func)
   
    # param_dist = {'n_estimators': stats.randint(50, 500),
    #               'learning_rate': stats.uniform(0.01, 0.07),
    #               'subsample': stats.uniform(0.3, 0.7),
    #               'max_depth': [3, 4, 5, 6],
    #               'colsample_bytree': stats.uniform(0.5, 0.45),
    #               'min_child_weight': [1, 2, 3],
    #               "gamma" : [0.01, 0.1, 0.3, 0.5, 1, 1.5, 2],
    #               "reg_alpha": [0, 0.5, 1],
    #              }
    param_dist = {'regressor__n_estimators': stats.randint(50, 150),
              'regressor__learning_rate': stats.uniform(0.01, 0.07),
              'regressor__subsample': stats.uniform(0.3, 0.7),
              'regressor__max_depth': [3, 4, 5, 6],
              'regressor__colsample_bytree': stats.uniform(0.5, 0.45),
              'regressor__min_child_weight': [1, 2, 3],
              "regressor__gamma" : [0.01, 0.1, 0.3, 0.5, 1, 1.5, 2],
              "regressor__reg_alpha": [0, 0.5, 1],
             }

    reg = RandomizedSearchCV(xg_reg_trans, 
                             param_distributions = param_dist,
#                              cv = 5,
                             cv=train_gkf,
                             n_iter = 2, 
                             scoring = 'neg_mean_squared_error',
                             error_score = 0,
                             verbose = 3,
                             n_jobs = -1)
    reg.fit(X_train[features_cols], X_train[runtime_col],
#             sample_weight=train_samples_weight,
            groups=train_groups
            )
#     xg_reg_trans.fit(X_train[features_cols], X_train[runtime_col],sample_weight=train_samples_weight )
    
    xg_regs.append(reg.best_estimator_)
# Out:
# 0 : A*+OD+ID Runtime
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   30.5s remaining:  1.2min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   36.3s remaining:   15.5s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   43.2s finished
# C:\Users\omri\AppData\Roaming\Python\Python36\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# 1 : MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   15.8s remaining:   37.1s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   33.9s remaining:   14.5s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   34.4s finished
# C:\Users\omri\AppData\Roaming\Python\Python36\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# 2 : Basic-CBS/(A*/SIC)+ID Runtime
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    7.6s remaining:   18.0s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   10.3s remaining:    4.3s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   13.3s finished
# C:\Users\omri\AppData\Roaming\Python\Python36\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# 3 : ICTS 3E +ID Runtime
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   15.0s remaining:   35.1s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   25.5s remaining:   10.9s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   26.4s finished
# C:\Users\omri\AppData\Roaming\Python\Python36\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# 4 : EPEA*+ID Runtime
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   17.0s remaining:   39.7s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   17.7s remaining:    7.5s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   24.6s finished
# C:\Users\omri\AppData\Roaming\Python\Python36\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# 5 : CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:   21.1s remaining:   49.4s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:   30.2s remaining:   12.9s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   34.2s finished
# C:\Users\omri\AppData\Roaming\Python\Python36\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
import numpy as np

from sklearn.metrics import mean_squared_error, median_absolute_error, mean_absolute_error

rmses = []
for xg_reg, reg_data in zip(xg_regs, regs_data):
    print("test label mean", np.std(reg_data[3]))
    reg_train_preds = xg_reg.predict(reg_data[0])
    reg_test_preds = xg_reg.predict(reg_data[1])
    print("Train acc:",np.sqrt(mean_squared_error(reg_data[2], reg_train_preds)))
    rmses.append(np.sqrt(mean_squared_error(reg_data[3], reg_test_preds)))
    print("Test acc:",np.sqrt(mean_squared_error(reg_data[3], reg_test_preds)))
# Out:
# test label mean 130510.69233219023
# Train acc: 99447.58138143376
# Test acc: 114556.25177461705
# test label mean 146681.43569104106
# Train acc: 148695.39658730687
# Test acc: 146958.71375712164
# test label mean 144393.99039350115
# Train acc: 182330.90818888132
# Test acc: 187026.25454443033
# test label mean 124049.52588138283
# Train acc: 95002.13860114888
# Test acc: 108709.61520378891
# test label mean 120570.6939219458
# Train acc: 96983.87861394788
# Test acc: 110243.1272651802
# test label mean 111789.67694181632
# Train acc: 99465.70574260505
# Test acc: 98151.1419658684

# %%
np.mean(rmses)
# Out:
# 127607.51741850108

# %% [markdown]
# #### Let's plot the histogram of the preidcted (log-transformed runtime) of each regressor ####

# %%
fig, axes = plt.subplots(3, 2, sharey=True, sharex=True, figsize=(10,5))
index =0

for xg_reg, reg_data in zip(xg_regs, regs_data):
    reg_test_preds = xg_reg.predict(reg_data[1])
    print([p for p in reg_test_preds if p > 300000], conversions[index])
    axes[index%3][index%2].hist(reg_test_preds)
    axes[index%3][index%2].set_title(conversions[index])
    index += 1
# Out:
# [344710.3, 304867.53, 314144.6, 305569.03, 305569.03, 310556.66, 301135.6, 302690.7, 304014.8] EPEA*+ID Runtime
# [317782.2, 307911.03, 307911.03, 319600.28, 325966.62, 325966.62, 375422.03, 375422.03, 387569.06, 422612.4, 448716.03, 501582.56] MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime
# [] ICTS 3E +ID Runtime
# [378578.75, 423104.4, 369255.66, 335574.84] A*+OD+ID Runtime
# [] Basic-CBS/(A*/SIC)+ID Runtime
# [307420.44, 304426.22, 304426.22, 304426.22, 326105.94, 343222.7, 382370.5, 382370.5, 387979.94, 403015.03, 403015.03, 403015.03, 397313.6, 397313.6, 397313.6, 397313.6, 397313.6, 397313.6, 397313.6, 397313.6, 397313.6, 397313.6, 410796.5, 393356.03, 393356.03, 393356.03, 393356.03, 396230.28, 396230.28, 396230.28, 396230.28, 396230.28, 396230.28, 396230.28, 396230.28, 396230.28, 396230.28, 396230.28, 396230.28, 396230.28, 396230.28, 303045.1, 351387.12, 351387.12, 395968.12, 384693.1, 374784.56, 326249.03, 302228.3, 333934.53, 313795.78, 333237.5, 443847.56, 424246.66, 479642.84, 510622.5, 510622.5, 510622.5, 510622.5, 477271.94, 526786.2, 442867.47, 479433.38, 442867.47, 479433.38, 479433.38, 479433.38, 479433.38, 479433.38, 511460.78, 479433.38, 442867.47, 433181.03, 433181.03, 433181.03, 433181.03, 438456.12, 438456.12, 438456.12, 438456.12, 441659.9, 441659.9, 441659.9, 441659.9, 441659.9, 441659.9, 441659.9, 441659.9, 478126.12, 478126.12, 441659.9, 478126.12, 478126.12, 316895.75] CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime

# %%
xg_test_res = []
xg_train_res = []
xg_y = []
for xg_reg in xg_regs:
    xg_test_res.append(np.array(xg_reg.predict(X_test[features_cols])))
    xg_train_res.append(np.array(xg_reg.predict(X_train[features_cols])))
xg_test_res = np.array(xg_test_res)
xg_train_res = np.array(xg_train_res)

# print(xg_res.argmin(axis=0)[:4], xg_res[:,:4]) #SANITY CHECK

train_preds = [conversions[index] for index in xg_train_res.argmin(axis=0)]
test_preds = [conversions[index] for index in xg_test_res.argmin(axis=0)]
print("Regressors argmax Train acc:",accuracy_score(y_train, train_preds))
print("Regressors argmax Test acc:",accuracy_score(y_test, test_preds ))
print("Regressors argmax Train coverage:", coverage_score(X_train, train_preds))
print("Regressors argmax Test coverage:", coverage_score(X_test, test_preds))
print("Regressors argmax Test cumsum:", cumsum_score(X_test, test_preds))
# Out:
# Regressors argmax Train acc: 0.3264293767112256
# Regressors argmax Test acc: 0.3014342235410485
# Regressors argmax Train coverage: 0.8036398775970366
# Regressors argmax Test coverage: 0.7788081107814046
# Regressors argmax Test cumsum: 10462.550895218332

# %%
# xg_regs[1].regressor_.save_model('testing.xgb') - Saving model that way will able to load cross-languages

# %%
reg_model = xgb.XGBRegressor()
reg_model.load_model('testing.xgb')

# %% [markdown]
# ## Regressors feature importance ##

# %%
for index, xg_reg in enumerate(xg_regs):
#     print(xg_reg.regressor_.feature_importances_)
    xgb.plot_importance(xg_reg.regressor_, importance_type='weight', title=conversions[index])

# %% [markdown]
# ### In order to deal with censored data (max_runtime limit), we use Scmhee and Hahn(1979) method - after training with censored data without any special consideration, we train again, but this time using the prediction of the trained model as the label for the censored data ###

# %%
# for runtime_col in runtime_cols:
#     if 'P Runtime' in runtime_col or 'Y Runtime' in runtime_col:
#         continue
#     print(runtime_col)
#     for index,(y,pred) in enumerate(zip(X_train[runtime_col].values,reg_train_preds)):
#         if(y==300000.0):
#             print(y,pred, index, runtime_col)
#             print(X_train[runtime_col].iat[index])
#             X_train[runtime_col].iat[index]=pred

## IN COMMENT SINCE MADE A DRASTIC DECREASE IN COVERAGE (99->95)

# %%
features_with_reg_cols = features_cols.copy()
for key, conversion in conversions.items():
    X_test['P ' + conversion] = xg_test_res[key]
    X_train['P ' + conversion] = xg_train_res[key]
    features_with_reg_cols.append('P ' + conversion)

# %% [markdown]
# #### Let's visualize coverage plot ####

# %%
## Adding CNN Results ##

# %%
# cnn_train_preds = np.load('train_preds.txt.npy')
# cnn_test_preds = np.load('test_preds.txt.npy')
# [cnn_test_preds)

# %%
#y-axis = coverage, x-axis=time, draw line for each algorithm/model/oracle
coverages = {}
coverages['Random'] = {}
cols = runtime_cols
if 'P Runtime' not in cols:
    cols.append('P Runtime')

for i in range(1, 5000, 100):
    for runtime_col in runtime_cols:
        if 'P Runtime' in runtime_col:
            elem = coverage_score(X_test, test_preds, i)
        else:
            elem = coverage_score(X_test, [runtime_col]*len(X_test), i)
        if runtime_col in coverages:
            coverages[runtime_col][i/1000] = elem
        else:
            coverages[runtime_col] = {}
            coverages[runtime_col][i/1000] = elem
    
    coverages['Random'][i/1000] = coverage_score(X_test,random_preds,i)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-7e1c9975a113> in <module>
#      11             elem = coverage_score(X_test, test_preds, i)
#      12         else:
# ---> 13             elem = coverage_score(X_test, [runtime_col]*len(X_test), i)
#      14         if runtime_col in coverages:
#      15             coverages[runtime_col][i/1000] = elem
#
# <ipython-input-21-dd2def7246bc> in coverage_score(df, preds, max_runtime)
#       2     tmp_df = df.copy()
#       3     tmp_df['CurrP'] = preds
# ----> 4     tmp_df['CurrP-Runtime'] = tmp_df.apply(lambda x: x[x['CurrP']], axis=1)
#       5     solved = len(tmp_df[tmp_df['CurrP-Runtime'] < max_runtime])
#       6     return solved/len(tmp_df)
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\pandas\core\apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     239             # Create a dummy Series from an empty array
#     240             from pandas import Series
# --> 241             values = self.values
#     242             index = self.obj._get_axis(self.axis)
#     243             labels = self.agg_axis
#
# pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\pandas\core\apply.py in values(self)
#      97     @cache_readonly
#      98     def values(self):
# ---> 99         return self.obj.values
#     100
#     101     @cache_readonly
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in values(self)
#    5323         """
#    5324         self._consolidate_inplace()
# -> 5325         return self._data.as_array(transpose=self._AXIS_REVERSED)
#    5326
#    5327     @property
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\pandas\core\internals\managers.py in as_array(self, transpose, items)
#     766             arr = np.asarray(mgr.blocks[0].get_values())
#     767         else:
# --> 768             arr = mgr._interleave()
#     769
#     770         return arr.transpose() if transpose else arr
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\pandas\core\internals\managers.py in _interleave(self)
#     791         for blk in self.blocks:
#     792             rl = blk.mgr_locs
# --> 793             result[rl.indexer] = blk.get_values(dtype)
#     794             itemmask[rl.indexer] = 1
#     795
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\pandas\core\internals\blocks.py in get_values(self, dtype)
#     179         """
#     180         if is_object_dtype(dtype):
# --> 181             return self.values.astype(object)
#     182         return self.values
#     183
#
# KeyboardInterrupt:

# %%
test_preds

# %%
# df[df['Y Runtime']>150000][df.ObstacleDensity<0.2][df.PointsAtSPRatio<0.5]

# %%
linestyle_str = [
     ('solid', 'solid'),      # Same as (0, ()) or '-'
     ('dotted', 'dotted'),    # Same as (0, (1, 1)) or '.'
     ('dashed', 'dashed'),    # Same as '--'
     ('dashdot', 'dashdot')]  # Same as '-.'

linestyle_tuple = [
     ('loosely dotted',        (0, (1, 10))),
     ('dotted',                (0, (1, 1))),
     ('densely dotted',        (0, (1, 1))),

     ('loosely dashed',        (0, (5, 10))),
     ('dashed',                (0, (5, 5))),
     ('densely dashed',        (0, (5, 1))),

     ('loosely dashdotted',    (0, (3, 10, 1, 10))),
     ('dashdotted',            (0, (3, 5, 1, 5))),
     ('densely dashdotted',    (0, (3, 1, 1, 1))),

     ('dashdotdotted',         (0, (3, 5, 1, 5, 1, 5))),
     ('loosely dashdotdotted', (0, (3, 10, 1, 10, 1, 10))),
     ('densely dashdotdotted', (0, (3, 1, 1, 1, 1, 1)))]


def line_style_for_model(model):
      return {
          'EPEA*+ID Runtime': (0, (1, 1)), #densely dotted
          'MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime':'dashed',
          'ICTS 3E +ID Runtime':(0, (1, 10)), #loosely dotted
          'A*+OD+ID Runtime':'dotted',
          'Basic-CBS/(A*/SIC)+ID Runtime':'dashdot',
          'CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime':(0, (5, 10)),
          'Y Runtime':'solid',
          'P Runtime':'solid',
          'Random':'solid'
      }[model]

# %%
ax = plt.gca()
plt.rcParams["figure.figsize"] = (10,7)
sorted_runtime_cols = runtime_cols
i=1
for runtime_col in sorted_runtime_cols:
    print(runtime_col)
    lists = sorted(coverages[runtime_col].items())
    x, y = zip(*lists)
#     if(runtime_col)
    ax.plot(x,y,linestyle=line_style_for_model(runtime_col))
    i+=1
    
ax.legend([folder_from_label(r) for r in sorted_runtime_cols], prop={'size': 16})

plt.show()

# %% [markdown]
# ## Classification using Pair-Wise models as SATZilla 2012 ##

# %%
def is_first_model_win(row,first_model,second_model):
    if row[first_model]<row[second_model]:
        return True
    return False

# %%
from sklearn.compose import TransformedTargetRegressor
from sklearn.model_selection import StratifiedKFold,cross_val_score, RandomizedSearchCV, GridSearchCV
from scipy import stats



pair_clfs = []
pairs_data = []
index = 0
for runtime_col in alg_runtime_cols:
    if 'Y Runtime' in runtime_col:
        continue
    for second_runtime_col in alg_runtime_cols:
        if 'Y Runtime' in second_runtime_col or runtime_col==second_runtime_col:
            continue
        index += 1
        label_name=folder_from_label(runtime_col)+'-vs-'+folder_from_label(second_runtime_col)
        print(index,":",label_name)
        X_train[label_name] = X_train.apply(lambda x: is_first_model_win(x,runtime_col, second_runtime_col), axis=1)
        X_test[label_name] = X_test.apply(lambda x: is_first_model_win(x,runtime_col, second_runtime_col), axis=1)
        
        pairs_data.append([X_train[features_cols],X_test[features_cols], X_train[label_name], X_test[label_name]])
        xg_cls = xgb.XGBClassifier(objective = 'binary:logistic')
        pair_sample_weight=np.log1p(abs(X_train[runtime_col]-X_train[second_runtime_col]))

        # param_dist = {'n_estimators': stats.randint(50, 500),
        #               'learning_rate': stats.uniform(0.01, 0.07),
        #               'subsample': stats.uniform(0.3, 0.7),
        #               'max_depth': [3, 4, 5, 6],
        #               'colsample_bytree': stats.uniform(0.5, 0.45),
        #               'min_child_weight': [1, 2, 3],
        #               "gamma" : [0.01, 0.1, 0.3, 0.5, 1, 1.5, 2],
        #               "reg_alpha": [0, 0.5, 1],
        #              }
        param_dist = {'n_estimators': stats.randint(50, 100),
                      'learning_rate': stats.uniform(0.01, 0.07),
                      'subsample': stats.uniform(0.3, 0.7),
                      'max_depth': [3, 4, 5, 6,],
                      'colsample_bytree': stats.uniform(0.5, 0.45),
                      'min_child_weight': [1, 2, 3],
                      "gamma": [0.01, 0.5, 1, 1.5, 2],
                      "reg_alpha": [0, 0.5, 1],
                      }

        cls = RandomizedSearchCV(xg_cls, 
                                 param_distributions = param_dist,
    #                              cv = 5,
                                 cv=train_gkf,
                                 n_iter = 1, 
#                                  scoring = 'neg_mean_squared_error',
#                                  error_score = 0,
                                 verbose = 3,
                                 n_jobs = -1)
        cls.fit(X_train[features_cols], X_train[label_name],
                sample_weight=pair_sample_weight,
                groups=train_groups
                )

        pair_clfs.append(cls.best_estimator_)
# Out:
# 1 : A*-vs-MA-CBS
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    5.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    5.9s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 2 : A*-vs-CBS
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    2.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    2.6s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 3 : A*-vs-ICTS
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    2.2s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 4 : A*-vs-EPEA*
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.3s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 5 : A*-vs-CBS-H
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.2s finished
# C:\Users\omri\AppData\Roaming\Python\Python36\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 6 : MA-CBS-vs-A*
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.5s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 7 : MA-CBS-vs-CBS
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.4s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 8 : MA-CBS-vs-ICTS
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    2.1s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 9 : MA-CBS-vs-EPEA*
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    6.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    6.1s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 10 : MA-CBS-vs-CBS-H
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.0s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 11 : CBS-vs-A*
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.2s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 12 : CBS-vs-MA-CBS
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.6s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 13 : CBS-vs-ICTS
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    2.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    2.8s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 14 : CBS-vs-EPEA*
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.6s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 15 : CBS-vs-CBS-H
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    4.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    4.8s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 16 : ICTS-vs-A*
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    4.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    4.3s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 17 : ICTS-vs-MA-CBS
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.9s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 18 : ICTS-vs-CBS
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    6.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    6.1s finished
# C:\Users\omri\AppData\Roaming\Python\Python36\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 19 : ICTS-vs-EPEA*
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    4.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    4.1s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 20 : ICTS-vs-CBS-H
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    5.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    5.8s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 21 : EPEA*-vs-A*
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    8.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    8.2s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 22 : EPEA*-vs-MA-CBS
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    3.9s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 23 : EPEA*-vs-CBS
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    6.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    6.1s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 24 : EPEA*-vs-ICTS
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    2.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    2.0s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 25 : EPEA*-vs-CBS-H
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    4.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    4.1s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 26 : CBS-H-vs-A*
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    5.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    5.2s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 27 : CBS-H-vs-MA-CBS
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    4.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    4.5s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 28 : CBS-H-vs-CBS
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    5.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    5.6s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 29 : CBS-H-vs-ICTS
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    2.1s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 30 : CBS-H-vs-EPEA*
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    2.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    2.6s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \

# %%
len(pairs_test_res)
# Out:
# 30

# %%
# pairs_test_res = []
# pairs_train_res = []
# pair_y = []
# for pair_cls in pair_clfs:
#     pairs_test_res.append(np.array(pair_cls.predict(X_test[features_cols])))
#     pairs_train_res.append(np.array(pair_cls.predict(X_train[features_cols])))
# pairs_test_res = np.array(pairs_test_res)
# pairs_train_res = np.array(pairs_train_res)

index = 0
for runtime_col in alg_runtime_cols:
    if 'Y' in runtime_col:
        continue
    for second_runtime_col in alg_runtime_cols:
        if 'Y Runtime' in second_runtime_col or runtime_col==second_runtime_col:
            continue
        p_label_name='P'+folder_from_label(runtime_col)+'-vs-'+folder_from_label(second_runtime_col)
        X_train[p_label_name] = pair_clfs[index].predict(X_train[features_cols])
        X_test[p_label_name] = pair_clfs[index].predict(X_test[features_cols])
        index += 1

# print(xg_res.argmin(axis=0)[:4], xg_res[:,:4]) #SANITY CHECK
# train_preds = [conversions[index] for index in pairs_train_res.argmin(axis=0)]
# test_preds = [conversions[index] for index in pairs_test_res.argmin(axis=0)]
# print("Regressors argmax Train acc:",accuracy_score(y_train, train_preds))
# print("Regressors argmax Test acc:",accuracy_score(y_test, test_preds ))
# print("Regressors argmax Train coverage:", coverage_score(X_train, train_preds))
# print("Regressors argmax Test coverage:", coverage_score(X_test, test_preds))
# print("Regressors argmax Test cumsum:", cumsum_score(X_test, test_preds))

# %%
def num_of_wins(df, model):
    wins = [0]*len(df)
    for runtime_col in alg_runtime_cols:
        if 'Y' in runtime_col or runtime_col==model:
            continue
        p_label_name='P'+folder_from_label(model)+'-vs-'+folder_from_label(runtime_col)
        wins+=df[p_label_name]
    return wins
win_cols = []
for runtime_col in alg_runtime_cols:
    if 'Y' in runtime_col:
        continue
    win_col = folder_from_label(runtime_col)+'-wins'
    X_train[win_col] = num_of_wins(X_train, runtime_col)
    X_test[win_col] = num_of_wins(X_test, runtime_col)
    win_cols.append(win_col)

# %%
train_preds = [label_from_folder(index.split('-win')[0]) for index in X_train[win_cols].idxmax(axis=1)]
test_preds = [label_from_folder(index.split('-win')[0]) for index in X_test[win_cols].idxmax(axis=1)]
print("Regressors argmax Train acc:",accuracy_score(y_train, train_preds))
print("Regressors argmax Test acc:",accuracy_score(y_test, test_preds ))
print("Regressors argmax Train coverage:", coverage_score(X_train, train_preds))
print("Regressors argmax Test coverage:", coverage_score(X_test, test_preds))
print("Regressors argmax Test cumsum:", cumsum_score(X_test, test_preds))
# Out:
# Regressors argmax Train acc: 0.6362699307456917
# Regressors argmax Test acc: 0.5940900098911969
# Regressors argmax Train coverage: 0.9586406828796907
# Regressors argmax Test coverage: 0.929648862512364
# Regressors argmax Test cumsum: 4461.07565208

# %%
index = 0
for runtime_col in alg_runtime_cols:
    if 'Y Runtime' in runtime_col:
        continue
    for second_runtime_col in alg_runtime_cols:
        if 'Y Runtime' in second_runtime_col or runtime_col==second_runtime_col:
            continue
        label_name=folder_from_label(runtime_col)+'-vs-'+folder_from_label(second_runtime_col)
        print(index,":",label_name)
        print("Pair wise classifier Train acc:",accuracy_score(X_train[label_name], pairs_train_res[index]))
        print("Pair wise classifier Test acc:",accuracy_score(X_test[label_name], pairs_test_res[index]))
        index += 1
# Out:
# 0 : A*-vs-MA-CBS
# Pair wise classifier Train acc: 0.8088903205024964
# Pair wise classifier Test acc: 0.6551681503461919
# 1 : A*-vs-CBS
# Pair wise classifier Train acc: 0.7985504912224191
# Pair wise classifier Test acc: 0.5806132542037586
# 2 : A*-vs-ICTS
# Pair wise classifier Train acc: 0.7788371718473184
# Pair wise classifier Test acc: 0.7561819980217607
# 3 : A*-vs-EPEA*
# Pair wise classifier Train acc: 0.804155258495732
# Pair wise classifier Test acc: 0.8311078140454995
# 4 : A*-vs-CBS-H
# Pair wise classifier Train acc: 0.8724754388790465
# Pair wise classifier Test acc: 0.8447082096933729
# 5 : MA-CBS-vs-A*
# Pair wise classifier Train acc: 0.8903849251087131
# Pair wise classifier Test acc: 0.8407517309594461
# 6 : MA-CBS-vs-CBS
# Pair wise classifier Train acc: 0.9142212916733774
# Pair wise classifier Test acc: 0.8285113748763601
# 7 : MA-CBS-vs-ICTS
# Pair wise classifier Train acc: 0.8982122725076502
# Pair wise classifier Test acc: 0.8334569732937686
# 8 : MA-CBS-vs-EPEA*
# Pair wise classifier Train acc: 0.7760025769044935
# Pair wise classifier Test acc: 0.7903066271018794
# 9 : MA-CBS-vs-CBS-H
# Pair wise classifier Train acc: 0.6708004509582863
# Pair wise classifier Test acc: 0.6808852621167161
# 10 : CBS-vs-A*
# Pair wise classifier Train acc: 0.7258817845063618
# Pair wise classifier Test acc: 0.6685212660731948
# 11 : CBS-vs-MA-CBS
# Pair wise classifier Train acc: 0.8041230471895635
# Pair wise classifier Test acc: 0.8167655786350149
# 12 : CBS-vs-ICTS
# Pair wise classifier Train acc: 0.5251087131583185
# Pair wise classifier Test acc: 0.5971810089020771
# 13 : CBS-vs-EPEA*
# Pair wise classifier Train acc: 0.6230310839104526
# Pair wise classifier Test acc: 0.621538081107814
# 14 : CBS-vs-CBS-H
# Pair wise classifier Train acc: 0.8034788210661943
# Pair wise classifier Test acc: 0.8083580613254204
# 15 : ICTS-vs-A*
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-179-8b790d43bddb> in <module>
#       8         label_name=folder_from_label(runtime_col)+'-vs-'+folder_from_label(second_runtime_col)
#       9         print(index,":",label_name)
# ---> 10         print("Pair wise classifier Train acc:",accuracy_score(X_train[label_name], pairs_train_res[index]))
#      11         print("Pair wise classifier Test acc:",accuracy_score(X_test[label_name], pairs_test_res[index]))
#      12         index += 1
#
# IndexError: index 15 is out of bounds for axis 0 with size 15

# %%
runtime_col = 'A*+OD+ID Runtime'
second_runtime_col = 'ICTS 3E +ID Runtime'

# X_train[folder_from_label(runtime_col)+'-vs-'+folder_from_label(second_runtime_col)] = X_train.apply(lambda x: is_first_model_win(x,runtime_col, other_runtime_col), axis=1)
# X_train[runtime_col]-X_train[second_runtime_col]
# folder_from_label(runtime_col)+'-vs-'+folder_from_label(second_runtime_col)
X_train.apply(lambda x: is_first_model_win(x,runtime_col, second_runtime_col), axis=1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
# 5         True
# 6        False
# 7        False
# 8         True
# 9         True
# 10        True
# 11       False
# 12       False
# 13       False
# 14       False
# 15        True
# 16       False
# 17       False
# 18        True
# 19        True
# 20       False
# 21        True
# 22        True
# 23       False
# 24        True
# 25       False
# 26        True
# 27       False
# 28       False
# 29        True
#          ...
# 31015    False
# 31016    False
# 31017    False
# 31018    False
# 31019    False
# 31020    False
# 31021    False
# 31022    False
# 31023    False
# 31024    False
# 31025    False
# 31026    False
# 31027    False
# 31028    False
# 31029    False
# 31030    False
# 31031    False
# 31032    False
# 31033    False
# 31034    False
# 31035    False
# 31036    False
# 31037    False
# 31038    False
# 31039    False
# 31040    False
# 31041    False
# 31042    False
# 31043    False
# 31044    False
# Length: 31045, dtype: bool

# %% [markdown]
# ## Classification model ##

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight(
               'balanced',  
                X_train['Y'].unique(), 
                X_train['Y'].values)  

class_weights
# Out:
# array([ 2.9190387 ,  1.31165554,  0.73147146,  2.92060094, 37.63546798,
#        34.64852608,  0.24212538])

# %%
# # X_train, X_test, y_train, y_test = train_test_split(solved_df, solved_df['Y'], test_size=0.3)

# xg_cls = xgb.XGBClassifier(n_estimators=350, max_depth=3, learning_rate=0.01)

# xg_cls.fit(X_train[features_cols], y_train, sample_weight=train_samples_weight)

from sklearn.model_selection import GroupKFold, LeavePGroupsOut, GroupShuffleSplit
train_groups = X_train['InstanceId'] #len of scenarios
# train_gkf = LeaveOneGroupOut()
train_gkf = GroupShuffleSplit(n_splits=5, test_size=0.3)

# group_kfold.get_n_splits(solved_df, solved_df['Y'])

# gkf = list(GroupKFold( n_splits=2).split(solved_df,solved_df['Y'],solved_df['InstanceId']))

# %%
cmap_cv = plt.cm.coolwarm
cmap_data = plt.cm.Paired
# %matplotlib inline
fig, ax = plt.subplots()

plot_cv_indices(train_gkf, X_train, [int_from_label(y) for y in y_train], X_train['InstanceId'], ax, 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-369698114ec5> in <module>
#       4 fig, ax = plt.subplots()
#       5
# ----> 6 plot_cv_indices(train_gkf, X_train, [int_from_label(y) for y in y_train], X_train['InstanceId'], ax, 2)
#
# <ipython-input-40-369698114ec5> in <listcomp>(.0)
#       4 fig, ax = plt.subplots()
#       5
# ----> 6 plot_cv_indices(train_gkf, X_train, [int_from_label(y) for y in y_train], X_train['InstanceId'], ax, 2)
#
# NameError: name 'int_from_label' is not defined

# %%
from sklearn.compose import TransformedTargetRegressor
from sklearn.model_selection import StratifiedKFold,cross_val_score, RandomizedSearchCV, GridSearchCV
from scipy import stats

xg_cls = xgb.XGBClassifier(objective = 'multi:softmax')

param_dist = {'n_estimators': stats.randint(50, 200),
              'learning_rate': stats.uniform(0.01, 0.07),
              'subsample': stats.uniform(0.3, 0.7),
              'max_depth': [ 4,5,6,7],
              # 'colsample_bytree': stats.uniform(0.5, 0.45),
              'min_child_weight': [1, 2, 3],
              "gamma": [0.1, 0.3, 0.5, 1, 1.5, 2],
              "reg_alpha": [0, 0.5, 1],
              }

clf = RandomizedSearchCV(xg_cls, 
                         param_distributions = param_dist,
#                          cv = 5,
                         cv=train_gkf,
                         n_iter = 2, 
#                          scoring = custom_scorer,
                         error_score = 0,
                         verbose = 3,
                         n_jobs = -1)

clf.fit(
    X_train[features_cols], X_train['Y'],
#         sample_weight=train_samples_weight,
        groups=train_groups,
#         scale_pos_weight=class_weights
       )
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:  3.4min remaining:  8.0min
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:  6.8min remaining:  2.9min
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  7.0min finished
# C:\Users\omri\AppData\Roaming\Python\Python36\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# RandomizedSearchCV(cv=GroupShuffleSplit(n_splits=5, random_state=None, test_size=0.3,
#          train_size=None),
#           error_score=0,
#           estimator=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='multi:softmax', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1),
#           fit_params=None, iid='warn', n_iter=2, n_jobs=-1,
#           param_distributions={'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001F18AF7E400>, 'learning_rate': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001F18AF7E2B0>, 'subsample': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001F18AF98DD8>, 'max_depth': [4, 5, 6, 7], 'min_child_weight': [1, 2, 3], 'gamma': [0.1, 0.3, 0.5, 1, 1.5, 2], 'reg_alpha': [0, 0.5, 1]},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score='warn', scoring=None, verbose=3)

# %%
# from sklearn.metrics import make_scorer

# def cov_scorer(y, y_pred, **kwargs):
#     max_runtime = kwargs['max_runtime'] #should be 300000 by default
#     df = kwargs['df'] #should be the df with runtime_cols
#     tmp_df = df.copy()
#     tmp_df = tmp_df
#     print(y_pred)
#     tmp_df['CurrP'] = y_pred
#     np.savetxt('predictions-coverage.txt',y_pred, )
    
#     tmp_df['CurrP-Runtime'] = tmp_df.apply(lambda x: x[x['CurrP']], axis=1)
#     solved = len(tmp_df[tmp_df['CurrP-Runtime'] < max_runtime])
#     return solved/len(tmp_df)

# custom_scorer = make_scorer(cov_scorer, greater_is_better=True,max_runtime=300000, df=X_train)

# %%
xg_cls = clf.best_estimator_

# %%
train_preds = xg_cls.predict(X_train[features_cols])
test_preds = xg_cls.predict(X_test[features_cols])

# %%
xg_cls.classes_
# Out:
# array(['A*+OD+ID Runtime', 'Basic-CBS/(A*/SIC)+ID Runtime',
#        'CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime',
#        'EPEA*+ID Runtime', 'ICTS 3E +ID Runtime',
#        'MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime',
#        'SAT Runtime'], dtype=object)

# %%
# X_train.to_csv("data/from-azure/splitted/train_features.csv", index=False)
# y_train.to_csv("data/from-azure/splitted/train_labels.csv", index=False, header=['Y'])
# X_test.to_csv("data/from-azure/splitted/test_features.csv", index=False)
# y_test.to_csv("data/from-azure/splitted/test_labels.csv", index=False, header=['Y'])

# %%
print("Train acc:",accuracy_score(y_train, train_preds))
print("Test acc:",accuracy_score(y_test, test_preds))

print("Train coverage:", coverage_score(X_train, train_preds))
print("Test coverage:", coverage_score(X_test, test_preds))

print("Train cumsum:", cumsum_score(X_train, train_preds))
print("Test cumsum:", cumsum_score(X_test, test_preds))
# Out:
# Train acc: 0.6340052356020942
# Test acc: 0.5997967938586588
# Train coverage: 0.6425916230366492
# Test coverage: 0.6113682546850305
# Train cumsum: 161523.91588333333
# Test cumsum: 40061.998583333334

# %%
xg_cls.save_model('testing-clf.xgb')

# %% [markdown]
# ## Classification model feature importance

# %%
import shap

# load JS visualization code to notebook
shap.initjs()
# plt.rcParams["figure.figsize"] = (15,8)

explainer = shap.TreeExplainer(xg_cls)
shap_values = explainer.shap_values(X_test[features_cols])

# visualize the first prediction's explanation (use matplotlib=True to avoid Javascript)
shap.summary_plot(shap_values, X_test[features_cols], class_names = [folder_from_label(c) for c in xg_cls.classes_],  plot_type="bar")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(9),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),y={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=y},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(18);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(185);n.d(e,"descending",function(){return a.a});var u=n(103);n.d(e,"deviation",function(){return u.a});var c=n(104);n.d(e,"extent",function(){return c.a});var s=n(186);n.d(e,"histogram",function(){return s.a});var l=n(197);n.d(e,"thresholdFreedmanDiaconis",function(){return l.a});var f=n(198);n.d(e,"thresholdScott",function(){return f.a});var p=n(107);n.d(e,"thresholdSturges",function(){return p.a});var h=n(188);n.d(e,"max",function(){return h.a});var d=n(189);n.d(e,"mean",function(){return d.a});var v=n(190);n.d(e,"median",function(){return v.a});var g=n(191);n.d(e,"merge",function(){return g.a});var y=n(105);n.d(e,"min",function(){return y.a});var m=n(192);n.d(e,"pairs",function(){return m.a});var _=n(193);n.d(e,"permute",function(){return ...

# %%
shap_values
# Out:
# [array([[-0.00032747,  0.        ,  0.        , ..., -0.00732447,
#          -0.00093338,  0.        ],
#         [-0.00032747,  0.        ,  0.        , ..., -0.00544302,
#          -0.00111422,  0.        ],
#         [-0.00032747,  0.        ,  0.        , ..., -0.00544302,
#          -0.00111422,  0.        ],
#         ...,
#         [-0.00032747,  0.        ,  0.        , ..., -0.01094121,
#          -0.0012548 ,  0.        ],
#         [-0.00032747,  0.        ,  0.        , ..., -0.01094121,
#          -0.0012548 ,  0.        ],
#         [-0.00032747,  0.        ,  0.        , ..., -0.01094121,
#          -0.0012548 ,  0.        ]], dtype=float32),
#  array([[-2.4464626e-02,  0.0000000e+00,  1.3401548e-03, ...,
#          -6.2157791e-03, -8.3892439e-03,  0.0000000e+00],
#         [-4.9536724e-02,  0.0000000e+00,  1.3401548e-03, ...,
#          -1.2163610e-02, -1.6071556e-02,  0.0000000e+00],
#         [-4.9536724e-02,  0.0000000e+00,  1.3401548e-03, ...,
#          -1.2163610e-02, -1.6071556e-02,  0.0000000e+00],
#         ...,
#         [ 1.3676894e-01,  0.0000000e+00,  2.2621836e-05, ...,
#           4.4195138e-02,  2.9198805e-02,  0.0000000e+00],
#         [ 1.3676894e-01,  0.0000000e+00,  2.2621836e-05, ...,
#           4.4195138e-02,  2.9198805e-02,  0.0000000e+00],
#         [ 1.3676894e-01,  0.0000000e+00,  2.2621836e-05, ...,
#           4.4195138e-02,  2.9198805e-02,  0.0000000e+00]], dtype=float32),
#  array([[-0.00826647, -0.0421557 , -0.02709724, ..., -0.00470235,
#          -0.03051262,  0.        ],
#         [-0.00811732, -0.04514885, -0.02632115, ..., -0.00444631,
#          -0.03138879,  0.        ],
#         [-0.00615673, -0.04817827, -0.02632115, ..., -0.00699925,
#          -0.02800419,  0.        ],
#         ...,
#         [-0.00811732,  0.06225112,  0.07492553, ..., -0.04687607,
#          -0.00480294,  0.        ],
#         [-0.00811732,  0.06225112,  0.07492553, ..., -0.04687607,
#          -0.00480294,  0.        ],
#         [-0.00811732,  0.06225112,  0.07492553, ..., -0.04687607,
#          -0.00480294,  0.        ]], dtype=float32),
#  array([[ 0.0000000e+00,  0.0000000e+00, -2.4239183e-05, ...,
#          -2.9012848e-02, -4.1411955e-02,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00, -2.4239183e-05, ...,
#          -3.4773652e-02, -5.3176790e-02,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00, -2.4239183e-05, ...,
#          -3.4722116e-02, -5.3176790e-02,  0.0000000e+00],
#         ...,
#         [ 0.0000000e+00,  0.0000000e+00,  1.6152739e-04, ...,
#           3.6300812e-02,  5.9650544e-02,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  1.6152739e-04, ...,
#           1.2281328e-01, -4.8607189e-02,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  1.6152739e-04, ...,
#           1.2281328e-01, -4.8607189e-02,  0.0000000e+00]], dtype=float32),
#  array([[ 0.00091077,  0.00279045,  0.00064088, ..., -0.17947713,
#          -0.20574473,  0.        ],
#         [ 0.00036573,  0.00279045,  0.00064126, ..., -0.18397811,
#          -0.20250212,  0.        ],
#         [ 0.00036573,  0.00279045,  0.00064126, ..., -0.18373027,
#          -0.20239116,  0.        ],
#         ...,
#         [ 0.00036602, -0.00292976,  0.00283211, ..., -0.15063566,
#           0.08022237,  0.        ],
#         [ 0.00036602, -0.00292976,  0.00283211, ..., -0.15063566,
#           0.08022237,  0.        ],
#         [ 0.00036602, -0.00292976,  0.00283211, ..., -0.15063566,
#           0.08022237,  0.        ]], dtype=float32),
#  array([[ 0.0131761 ,  0.00308895,  0.01409046, ...,  0.02994647,
#           0.07259265,  0.        ],
#         [ 0.01354066,  0.00323136,  0.01463019, ...,  0.02102149,
#           0.08038724,  0.        ],
#         [ 0.01354066,  0.00406922,  0.01544293, ...,  0.01782191,
#           0.08780936,  0.        ],
#         ...,
#         [-0.04032461, -0.00607648, -0.0268016 , ..., -0.00415756,
#           0.01422548,  0.        ],
#         [-0.04032461, -0.00607648, -0.0268016 , ..., -0.00423231,
#           0.01422548,  0.        ],
#         [-0.04032461, -0.00607648, -0.0268016 , ..., -0.00415756,
#           0.01422548,  0.        ]], dtype=float32)]

# %%
for index,solver in enumerate(xg_cls.classes_):
    print(solver,"Shap summary plot:")
    
#     shap.summary_plot(shap_values[index], X_test[features_cols], plot_type="bar", show=False)
#     plt.savefig("src/shap-new/simple-" + folder_from_label(solver), bbox_inches="tight")
#     plt.close('all')
# Out:
# A*+OD+ID Runtime Shap summary plot:
# Basic-CBS/(A*/SIC)+ID Runtime Shap summary plot:
# CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime Shap summary plot:
# EPEA*+ID Runtime Shap summary plot:
# ICTS 3E +ID Runtime Shap summary plot:
# MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime Shap summary plot:

# %%
shap.summary_plot(np.abs(np.array(shap_values)).mean(axis=0), X_test[features_cols], plot_type="bar", show=False)
plt.savefig("src/shap-new/mean_all_classes.png", bbox_inches="tight")
plt.close('all')

# %%
pd.DataFrame(np.abs(np.array(shap_values)).mean(axis=0), columns=features_cols).to_csv("mean_feat_imp.csv")

# %%
features_cols
# Out:
# ['GridRows',
#  'GridColumns',
#  'NumOfObstacles',
#  'AvgDistanceToGoal',
#  'MaxDistanceToGoal',
#  'MinDistanceToGoal',
#  'AvgStartDistances',
#  'AvgGoalDistances',
#  'NumOfAgents',
#  'ObstacleDensity',
#  'PointsAtSPRatio',
#  'Sparsity',
#  'BranchingFactor']

# %%
hard_samples = X_test[(X_test['P Runtime-results']>2) & (X_test['P Runtime']>10000)][features_cols + runtime_cols + ['Y'] + ['P']]
hard_samples.head(1).index.values[0]
# Out:
# 540

# %%
shap.force_plot(explainer.expected_value, shap_values[0,:], X_test.iloc[0,:])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-568-76279446e6a1> in <module>
# ----> 1 shap.force_plot(explainer.expected_value, shap_values[0,:], X_test.iloc[0,:])
#
# TypeError: list indices must be integers or slices, not tuple

# %%
shap.multioutput_decision_plot
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-572-0289ed2963f6> in <module>
# ----> 1 shap.multioutput_decision_plot
#
# AttributeError: module 'shap' has no attribute 'multioutput_decision_plot'

# %%
shap_values[0,:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-570-4e91f3c041d3> in <module>
# ----> 1 shap_values[0,:]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
X_test.iloc[540]
# Out:
# Unnamed: 0                                                                                          7979
# index                                                                                               7979
# GridName                                                                                     empty-48-48
# GridRows                                                                                              48
# GridColumns                                                                                           48
# NumOfAgents                                                                                          117
# NumOfObstacles                                                                                         0
# InstanceId                                                                                            16
# BranchingFactor                                                                              6.01853e+81
# ObstacleDensity                                                                                        0
# AvgDistanceToGoal                                                                                32.8291
# MaxDistanceToGoal                                                                                     77
# MinDistanceToGoal                                                                                      6
# AvgStartDistances                                                                                32.5487
# AvgGoalDistances                                                                                 32.4911
# PointsAtSPRatio                                                                                 0.782118
# A*+OD+ID Success                                                                                    True
# A*+OD+ID Runtime                                                                                 36925.3
# A*+OD+ID Solution Cost                                                                              3846
# A*+OD+ID Expanded                                                                                 200330
# A*+OD+ID Generated                                                                                706081
# A*+OD+ID Max Group Size                                                                                6
# A*+OD+ID Min Group Size                                                                                1
# A*+OD+ID Max Group                                                                                     6
# A*+OD+ID Solution Depth                                                                                5
# MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Success                      False
# MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime                     300000
# MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Solution Cost           irrelevant
# MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Expanded (HL)           irrelevant
# MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Generated (HL)          irrelevant
#                                                                                               ...
# embeddding38                                                                                           0
# embeddding39                                                                                           0
# embeddding40                                                                                           0
# embeddding41                                                                                      169001
# embeddding42                                                                                           0
# embeddding43                                                                                           0
# embeddding44                                                                                           0
# embeddding45                                                                                           0
# embeddding46                                                                                           0
# embeddding47                                                                                           0
# embeddding48                                                                                     22569.3
# embeddding49                                                                                           0
# embeddding50                                                                                           0
# embeddding51                                                                                           0
# embeddding52                                                                                      143584
# embeddding53                                                                                           0
# embeddding54                                                                                           0
# embeddding55                                                                                           0
# embeddding56                                                                                      116379
# embeddding57                                                                                      109408
# embeddding58                                                                                           0
# embeddding59                                                                                           0
# embeddding60                                                                                           0
# embeddding61                                                                                      257903
# embeddding62                                                                                           0
# embeddding63                                                                                           0
# P                                                                                       EPEA*+ID Runtime
# P Success                                                                                          False
# P Runtime                                                                                         300000
# P Runtime-results                                                                                      5
# Name: 540, Length: 229, dtype: object

# %%
shap.force_plot(explainer.expected_value, shap_values[0,:], Xv.iloc[0,:])

# %%
xgb.plot_importance(xg_cls, importance_type='gain')

# %%
feat_imps = pd.DataFrame(xg_cls.get_booster().get_score(
            importance_type='gain'))

# feat_imps = pd.DataFrame(xg_cls.feature_importances_)
# feat_imps['name'] = features_cols
feat_imps
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-532-e51f5e62a064> in <module>
#       1 feat_imps = pd.DataFrame(xg_cls.get_booster().get_score(
# ----> 2             importance_type='gain'))
#       3
#       4 # feat_imps = pd.DataFrame(xg_cls.feature_importances_)
#       5 # feat_imps['name'] = features_cols
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     306
#     307         if not indexes and not raw_lengths:
# --> 308             raise ValueError('If using all scalar values, you must pass'
#     309                              ' an index')
#     310
#
# ValueError: If using all scalar values, you must pass an index

# %%
weight_import = xg_cls.get_booster().get_score(
            importance_type='gain')
pd.DataFrame.from_dict(weight_import, orient='index',).to_csv('feat_imp_clf_regular.csv')

# %%
weight_import
# Out:
# {'NumOfAgents': 173.05219388589444,
#  'PointsAtSPRatio': 63.54250454296936,
#  'MaxDistanceToGoal': 28.865505297766504,
#  'AvgStartDistances': 30.6435896950188,
#  'AvgDistanceToGoal': 23.051714040629925,
#  'AvgGoalDistances': 18.28099117388888,
#  'MinDistanceToGoal': 13.176466060843683,
#  'Sparsity': 58.35107403732717,
#  'GridRows': 29.863493577367098,
#  'ObstacleDensity': 170.39467109930843,
#  'NumOfObstacles': 54.842685810294086,
#  'GridColumns': 90.84982121929825}

# %%
xg_cls
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=1.5, learning_rate=0.014655198170289499,
#        max_delta_step=0, max_depth=4, min_child_weight=2, missing=nan,
#        n_estimators=71, n_jobs=1, nthread=None, objective='multi:softprob',
#        random_state=0, reg_alpha=0.5, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=0.6329930451935214)

# %%
from pandas.plotting import table 

mean_class_shap = []
for class_vals in shap_values:
    mean_class_shap.append(class_vals.mean(0))

shap_df = pd.DataFrame(mean_class_shap, columns=features_cols)
shap_df.index = only_alg_runtime_cols
# shap_df
# plt.rcParams["figure.figsize"] = (15,8)
# fig, ax = plt.subplots(figsize=(16, 9))
# ax.xaxis.set_visible(False)  # hide the x axis
# ax.yaxis.set_visible(False)  # hide the y axis
# tabla = table(ax, shap_df, loc='upper right', colWidths=[0.17]*len(df.columns))  # where df is your data frame
# # tabla.auto_set_font_size(False) # Activate set fontsize manually
# tabla.set_fontsize(12) # if ++fontsize is necessary ++colWidths
# # tabla.scale(1.2, 1.2)
# plt.savefig('cls_feat_imp.jpg',bbox_inches='tight')
# # plt.show()

# %%
shap_df.to_csv('feat_imp_clf.csv')

# %%
feat_imps.to_csv('feat_imp_clf_regular.csv')

# %%
class_vals.mean(0)
# Out:
# array([-1.4899134e-04,  0.0000000e+00,  0.0000000e+00, -2.7009174e-03,
#        -6.4252189e-04, -1.3827924e-02,  2.2328556e-04,  8.9961555e-05,
#         8.7609724e-04,  0.0000000e+00,  4.2097368e-03,  1.4586211e-04,
#         0.0000000e+00], dtype=float32)

# %%
conversions[0]
# Out:
# 'EPEA*+ID Runtime'

# %%
vals= np.abs(shap_values).mean(0)
feature_importance = pd.DataFrame(list(zip(['col_name'],vals)),columns=['col_name','feature_importance_vals'])
feature_importance.sort_values(by=['feature_importance_vals'],ascending=False,inplace=True)
feature_importance.head()
# Out:
#    col_name                            feature_importance_vals
# 0  col_name  [0.007857572, 0.008005849, 0.007198829, 0.0177...

# %%
len(vals)
# Out:
# 8088

# %%
from collections import Counter
# print("Predicted:", Counter(test_preds))
# print("True:", Counter(X_test['Y']))
Counter(test_preds),  Counter(X_test['Y'])
# Out:
# (Counter({'ICTS 3E +ID Runtime': 2795,
#           'Basic-CBS/(A*/SIC)+ID Runtime': 685,
#           'MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime': 2840,
#           'A*+OD+ID Runtime': 791,
#           'EPEA*+ID Runtime': 1684}),
#  Counter({'ICTS 3E +ID Runtime': 2153,
#           'Basic-CBS/(A*/SIC)+ID Runtime': 771,
#           'MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime': 3824,
#           'EPEA*+ID Runtime': 1832,
#           'A*+OD+ID Runtime': 215}))

# %%
X_test['Y'].value_counts().plot(kind='pie', legend=False)

# %%
plt.pie(Counter(test_preds).values(),labels=Counter(test_preds).keys())
# Out:
# ([<matplotlib.patches.Wedge at 0x1f4f9d61a20>,
#   <matplotlib.patches.Wedge at 0x1f4f9b629b0>,
#   <matplotlib.patches.Wedge at 0x1f4f9b622b0>,
#   <matplotlib.patches.Wedge at 0x1f4f9b628d0>,
#   <matplotlib.patches.Wedge at 0x1f4f9c12710>],
#  [Text(0.5958313164995515, 0.9246540122004617, 'ICTS 3E +ID Runtime'),
#   Text(-0.6836422767962169, 0.8617617056802216, 'Basic-CBS/(A*/SIC)+ID Runtime'),
#   Text(-1.029878068944017, -0.3864597820060233, 'MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime'),
#   Text(0.09359872549289468, -1.0960106197414814, 'A*+OD+ID Runtime'),
#   Text(0.9069188665069947, -0.6224935096638906, 'EPEA*+ID Runtime')])

# %% [markdown]
# ### Binary classifiers for problem "solveness" per algorithm:

# %%
# Out:
# 'Y Success'

# %%
for runtime_col in runtime_cols:
    if 'P Runtime' in runtime_col or 'Y Runtime' in runtime_col:
        continue
    X_train[runtime_col+"-under1m"] = X_train[runtime_col].apply(lambda x: int(x<180000))
    X_test[runtime_col+"-under1m"] = X_test[runtime_col].apply(lambda x: int(x<180000))

# %%
from sklearn.utils import class_weight

xg_bi_clfs = []
clfs_data = []
index = 0
for runtime_col in runtime_cols:
    if 'P Runtime' in runtime_col or 'Y Runtime' in runtime_col:
        continue
    print(index,":",runtime_col)
    index += 1
#     label = runtime_to_success(runtime_col)
    label = runtime_col+"-under1m"
    clfs_data.append([X_train[features_cols],X_test[features_cols], X_train[label], X_test[label]])
    class_weights = class_weight.compute_class_weight(
               'balanced',  
                [1,0], 
                X_train[label].values)  
    num_pos = len([x for x in X_train[label] if x==1])
    num_neg = len([x for x in X_train[label] if x==0])
    print(num_neg/num_pos)
    
    param_dist = {'n_estimators': stats.randint(50, 300),
                  'learning_rate': stats.uniform(0.01, 0.6),
                  'subsample': stats.uniform(0.3, 0.9),
                  'max_depth': [3, 4, 5, 6],
                  'colsample_bytree': stats.uniform(0.5, 0.9),
                  'min_child_weight': [1, 2, 3, 4]
                 }
    
#     xg_bi_clf = xgb.XGBClassifier(n_estimators = 60,
#                                   max_depth=4,
#                                   subsample=0.9,
# #                                   scale_pos_weight = (num_neg/num_pos)*3,
#                                   learning_rate=0.1,
#                                   colsample_bytree=1)

    xg_bi_clf = xgb.XGBClassifier(objective = 'binary:logistic')

    clf = RandomizedSearchCV(xg_bi_clf, 
                         param_distributions = param_dist,
                         cv = 5,  
                         n_iter = 5, # you want 5 here not 25 if I understand you correctly 
                         scoring = 'roc_auc', 
                         error_score = 0, 
                         verbose = 3, 
                         n_jobs = -1)
    
    clf.fit(X_train[features_cols], X_train[label], sample_weight=train_samples_weight)
    
    xg_bi_clfs.append(clf)
# Out:
# 0 : EPEA*+ID Runtime
# 0.10333723653395785
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  25 | elapsed:   11.2s remaining:   16.9s
# [Parallel(n_jobs=-1)]: Done  19 out of  25 | elapsed:   14.3s remaining:    4.4s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   18.6s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 1 : MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime
# 0.693606367954808
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  25 | elapsed:   21.6s remaining:   32.5s
# [Parallel(n_jobs=-1)]: Done  19 out of  25 | elapsed:   26.2s remaining:    8.2s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   35.0s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 2 : ICTS 3E +ID Runtime
# 0.12430750873604364
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  25 | elapsed:    0.8s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   11.1s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 3 : A*+OD+ID Runtime
# 0.20278094369728744
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  25 | elapsed:    0.3s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  19 out of  25 | elapsed:   15.9s remaining:    5.0s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   40.9s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 4 : Basic-CBS/(A*/SIC)+ID Runtime
# 0.48997571581860283
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  25 | elapsed:    0.5s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  19 out of  25 | elapsed:    0.9s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    3.6s finished
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \

# %%
from sklearn.metrics import classification_report
xg_bi_res = []

for index, (xg_bi_clf, clf_data) in enumerate(zip(xg_bi_clfs, clfs_data)):
    print(conversions[index], "Binary classifier results:")
    bi_clf_train_preds = xg_bi_clf.predict(clf_data[0])
    bi_clf_test_preds = xg_bi_clf.predict(clf_data[1])
    
#     print("Train acc:",classification_report(clf_data[2], bi_clf_train_preds))
    print("Test acc:",classification_report(clf_data[3], bi_clf_test_preds))
    print("Always one (on test) acc:", classification_report(clf_data[3], [1]*(len(clf_data[3]))))
# Out:
# EPEA*+ID Runtime Binary classifier results:
# Test acc:               precision    recall  f1-score   support
#
#            0       0.89      0.63      0.74       842
#            1       0.96      0.99      0.98      7953
#
#    micro avg       0.96      0.96      0.96      8795
#    macro avg       0.92      0.81      0.86      8795
# weighted avg       0.95      0.96      0.95      8795
#
# Always one (on test) acc:               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       842
#            1       0.90      1.00      0.95      7953
#
#    micro avg       0.90      0.90      0.90      8795
#    macro avg       0.45      0.50      0.47      8795
# weighted avg       0.82      0.90      0.86      8795
#
# MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime Binary classifier results:
# C:\Users\omri\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Test acc:               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94      3687
#            1       0.96      0.95      0.96      5108
#
#    micro avg       0.95      0.95      0.95      8795
#    macro avg       0.95      0.95      0.95      8795
# weighted avg       0.95      0.95      0.95      8795
#
# Always one (on test) acc:               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      3687
#            1       0.58      1.00      0.73      5108
#
#    micro avg       0.58      0.58      0.58      8795
#    macro avg       0.29      0.50      0.37      8795
# weighted avg       0.34      0.58      0.43      8795
#
# ICTS 3E +ID Runtime Binary classifier results:
# Test acc:               precision    recall  f1-score   support
#
#            0       0.94      0.80      0.86       988
#            1       0.97      0.99      0.98      7807
#
#    micro avg       0.97      0.97      0.97      8795
#    macro avg       0.96      0.89      0.92      8795
# weighted avg       0.97      0.97      0.97      8795
#
# Always one (on test) acc:               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       988
#            1       0.89      1.00      0.94      7807
#
#    micro avg       0.89      0.89      0.89      8795
#    macro avg       0.44      0.50      0.47      8795
# weighted avg       0.79      0.89      0.83      8795
#
# A*+OD+ID Runtime Binary classifier results:
# Test acc:               precision    recall  f1-score   support
#
#            0       0.90      0.81      0.85      1460
#            1       0.96      0.98      0.97      7335
#
#    micro avg       0.95      0.95      0.95      8795
#    macro avg       0.93      0.90      0.91      8795
# weighted avg       0.95      0.95      0.95      8795
#
# Always one (on test) acc:               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1460
#            1       0.83      1.00      0.91      7335
#
#    micro avg       0.83      0.83      0.83      8795
#    macro avg       0.42      0.50      0.45      8795
# weighted avg       0.70      0.83      0.76      8795
#
# Basic-CBS/(A*/SIC)+ID Runtime Binary classifier results:
# Test acc:               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85      3002
#            1       0.92      0.93      0.92      5793
#
#    micro avg       0.90      0.90      0.90      8795
#    macro avg       0.89      0.89      0.89      8795
# weighted avg       0.90      0.90      0.90      8795
#
# Always one (on test) acc:               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      3002
#            1       0.66      1.00      0.79      5793
#
#    micro avg       0.66      0.66      0.66      8795
#    macro avg       0.33      0.50      0.40      8795
# weighted avg       0.43      0.66      0.52      8795

# %%
bi_clf_test_res = []
bi_clf_train_res = []
for bi_clf in xg_bi_clfs:
    bi_clf_test_res.append(np.array(bi_clf.predict(X_test[features_with_reg_cols])))
    bi_clf_train_res.append(np.array(bi_clf.predict(X_train[features_with_reg_cols])))
bi_clf_test_res = np.array(bi_clf_test_res)
bi_clf_train_res = np.array(bi_clf_train_res)

solved_X_train = X_train.copy()
solved_X_test = X_test.copy()
not_solved_X_test = X_test.copy()

features_with_bi_clf_cols = features_with_reg_cols.copy()
index=0
for runtime_col in runtime_cols:
    if 'P Runtime' in runtime_col or 'Y Runtime' in runtime_col:
        continue
    X_train[runtime_col+"-p-under1m"] = bi_clf_train_res[index]
    X_test[runtime_col+"-p-under1m"] = bi_clf_test_res[index]
    solved_X_train = X_train[X_train[runtime_col+"-p-under1m"]==1]
    solved_X_test = X_test[X_test[runtime_col+"-p-under1m"]==1]
    not_solved_X_test = X_test[X_test[runtime_col+"-p-under1m"]<0.5]

    print(runtime_col, len(solved_X_test), len(X_test[X_test[runtime_to_success(runtime_col)]==1]))
    print(runtime_col, len(not_solved_X_test), len(X_test[X_test[runtime_to_success(runtime_col)]==0]))

    index+=1
    if (runtime_col+"-p-under1m") not in features_with_bi_clf_cols:
        features_with_bi_clf_cols.append(runtime_col+"-p-under1m")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-a3276552bbf0> in <module>
#       2 bi_clf_train_res = []
#       3 for bi_clf in xg_bi_clfs:
# ----> 4     bi_clf_test_res.append(np.array(bi_clf.predict(X_test[features_with_reg_cols])))
#       5     bi_clf_train_res.append(np.array(bi_clf.predict(X_train[features_with_reg_cols])))
#       6 bi_clf_test_res = np.array(bi_clf_test_res)
#
# ~\AppData\Roaming\Python\Python36\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     116
#     117         # lambda, but not partial, allows help() to work with update_wrapper
# --> 118         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     119         # update the docstring of the returned function
#     120         update_wrapper(out, self.fn)
#
# ~\AppData\Roaming\Python\Python36\site-packages\sklearn\model_selection\_search.py in predict(self, X)
#     489         """
#     490         self._check_is_fitted('predict')
# --> 491         return self.best_estimator_.predict(X)
#     492
#     493     @if_delegate_has_method(delegate=('best_estimator_', 'estimator'))
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\sklearn.py in predict(self, data, output_margin, ntree_limit, validate_features)
#     770                                                  output_margin=output_margin,
#     771                                                  ntree_limit=ntree_limit,
# --> 772                                                  validate_features=validate_features)
#     773         if output_margin:
#     774             # If output_margin is active, simply return the scores
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py in predict(self, data, output_margin, ntree_limit, pred_leaf, pred_contribs, approx_contribs, pred_interactions, validate_features)
#    1283
#    1284         if validate_features:
# -> 1285             self._validate_features(data)
#    1286
#    1287         length = c_bst_ulong()
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\xgboost\core.py in _validate_features(self, data)
#    1690
#    1691                 raise ValueError(msg.format(self.feature_names,
# -> 1692                                             data.feature_names))
#    1693
#    1694     def get_split_value_histogram(self, feature, fmap='', bins=None, as_pandas=True):
#
# ValueError: feature_names mismatch: ['GridSize', 'NumOfObstacles', 'AvgDistanceToGoal', 'MaxDistanceToGoal', 'MinDistanceToGoal', 'AvgStartDistances', 'AvgGoalDistances', 'NumOfAgents', 'ObstacleDensity', 'PointsAtSPRatio', 'Sparsity'] ['GridSize', 'NumOfObstacles', 'AvgDistanceToGoal', 'MaxDistanceToGoal', 'MinDistanceToGoal', 'AvgStartDistances', 'AvgGoalDistances', 'NumOfAgents', 'ObstacleDensity', 'PointsAtSPRatio', 'Sparsity', 'P EPEA*+ID Runtime', 'P MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime', 'P ICTS 3E +ID Runtime', 'P A*+OD+ID Runtime', 'P Basic-CBS/(A*/SIC)+ID Runtime']
# training data did not have the following fields: P EPEA*+ID Runtime, P MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime, P A*+OD+ID Runtime, P ICTS 3E +ID Runtime, P Basic-CBS/(A*/SIC)+ID Runtime

# %% [markdown]
# ## Regression model feature importance ##

# %%
import shap

# load JS visualization code to notebook
shap.initjs()
index=0
for xgb_reg_obj in xg_regs:
    print(conversions[index])

    xgb_obj = xgb_reg_obj.regressor_
    explainer = shap.TreeExplainer(xgb_obj)
    shap_values = explainer.shap_values(X_test[features_cols])

    # visualize the first prediction's explanation (use matplotlib=True to avoid Javascript)
    shap.dependence_plot(shap_values, X_test[features_cols])
    index+=1
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(9),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),y={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=y},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(18);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(185);n.d(e,"descending",function(){return a.a});var u=n(103);n.d(e,"deviation",function(){return u.a});var c=n(104);n.d(e,"extent",function(){return c.a});var s=n(186);n.d(e,"histogram",function(){return s.a});var l=n(197);n.d(e,"thresholdFreedmanDiaconis",function(){return l.a});var f=n(198);n.d(e,"thresholdScott",function(){return f.a});var p=n(107);n.d(e,"thresholdSturges",function(){return p.a});var h=n(188);n.d(e,"max",function(){return h.a});var d=n(189);n.d(e,"mean",function(){return d.a});var v=n(190);n.d(e,"median",function(){return v.a});var g=n(191);n.d(e,"merge",function(){return g.a});var y=n(105);n.d(e,"min",function(){return y.a});var m=n(192);n.d(e,"pairs",function(){return m.a});var _=n(193);n.d(e,"permute",function(){return ...
# EPEA*+ID Runtime
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1084-51468c62b47e> in <module>
#      12
#      13     # visualize the first prediction's explanation (use matplotlib=True to avoid Javascript)
# ---> 14     shap.dependence_plot(["NumOfAgents","ObstacleDensity"],shap_values, X_test[features_cols])
#      15     index+=1
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\shap\plots\dependence.py in dependence_plot(ind, shap_values, features, feature_names, display_features, interaction_index, color, axis_color, dot_size, alpha, title, show)
#      99
#     100     # get both the raw and display feature values
# --> 101     xv = features[:, ind]
#     102     xd = display_features[:, ind]
#     103     s = shap_values[:, ind]
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
import shap

# load JS visualization code to notebook
shap.initjs()
index=0
for xgb_reg_obj in xg_regs:
    print(conversions[index])

    xgb_obj = xgb_reg_obj.regressor_
    explainer = shap.TreeExplainer(xgb_obj)
    shap_values = explainer.shap_values(X_test[features_cols])

    # visualize the first prediction's explanation (use matplotlib=True to avoid Javascript)
    shap.summary_plot(shap_values, X_test[features_cols])
    index+=1
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(9),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),y={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=y},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(18);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(185);n.d(e,"descending",function(){return a.a});var u=n(103);n.d(e,"deviation",function(){return u.a});var c=n(104);n.d(e,"extent",function(){return c.a});var s=n(186);n.d(e,"histogram",function(){return s.a});var l=n(197);n.d(e,"thresholdFreedmanDiaconis",function(){return l.a});var f=n(198);n.d(e,"thresholdScott",function(){return f.a});var p=n(107);n.d(e,"thresholdSturges",function(){return p.a});var h=n(188);n.d(e,"max",function(){return h.a});var d=n(189);n.d(e,"mean",function(){return d.a});var v=n(190);n.d(e,"median",function(){return v.a});var g=n(191);n.d(e,"merge",function(){return g.a});var y=n(105);n.d(e,"min",function(){return y.a});var m=n(192);n.d(e,"pairs",function(){return m.a});var _=n(193);n.d(e,"permute",function(){return ...
# EPEA*+ID Runtime
# MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime
# ICTS 3E +ID Runtime
# A*+OD+ID Runtime
# Basic-CBS/(A*/SIC)+ID Runtime
# CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime

# %%
import joblib
xg_cls = joblib.load('src/clf-model.xgb')
# xg_cls.predict_proba(X_test[features_cols].head(5))

# %%
xg_cls
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=1.5, learning_rate=0.014655198170289499,
#        max_delta_step=0, max_depth=4, min_child_weight=2, missing=nan,
#        n_estimators=71, n_jobs=1, nthread=None, objective='multi:softprob',
#        random_state=0, reg_alpha=0.5, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=0.6329930451935214)

# %% [markdown]
# ## Adding 'P Success' column to indicate if the predicted algorithm finished before 5 minutes

# %%
X_test['P'] = xg_cls.predict(X_test[features_cols])
# solved_df['P'] = xg_cls.predict(solved_df[features_with_reg_cols])

# %%
X_test['P Success'] = X_test.apply(lambda x:x[runtime_to_success(x['P'])], axis=1)
# solved_df['P Success'] = solved_df.apply(lambda x:x[runtime_to_success(x['P'])], axis=1)

# %%
# runtime_cols.remove('P Runtime')

# %%
X_test['P Runtime'] = X_test.apply(lambda x:x[x['P']], axis=1)
# solved_df['P Runtime'] = solved_df.apply(lambda x:x[x['P']], axis=1)

runtime_cols.append('P Runtime')

# %%
runtime_per_algo = {}
for runtime in runtime_cols:
    substr_index = runtime.rfind(')')
    if(substr_index!=-1):
        key = runtime[:substr_index+1]
    else:
        key = runtime
    print(runtime)
    runtime_per_algo[key] = X_test[runtime].sum()
# Out:
# A*+OD+ID Runtime
# MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime
# Basic-CBS/(A*/SIC)+ID Runtime
# ICTS 3E +ID Runtime
# EPEA*+ID Runtime
# CBS/(A*/SIC) + BP + PC without smart tie breaking using Dynamic Lazy Open List with Heuristic MVC of Cardinal Conflict Graph Heuristic Runtime
# Y Runtime
# P Runtime

# %%
mean_runtime_per_algo = {}
for runtime in runtime_cols:
    substr_index = runtime.rfind(')')
    if(substr_index!=-1):
        key = runtime[:substr_index+1]
    else:
        key = runtime
    mean_runtime_per_algo[key] = X_test[runtime].std(),  X_test[runtime].mean()  

mean_runtime_per_algo
# Out:
# {'A*+OD+ID Runtime': (130518.7612488465, 92432.14363077398),
#  'MA-CBS-Global-10/(EPEA*/SIC)': (146690.50437544126, 148015.52566362513),
#  'Basic-CBS/(A*/SIC)': (144402.91765496405, 129429.76315165678),
#  'ICTS 3E +ID Runtime': (124057.19533181406, 78415.34399761375),
#  'EPEA*+ID Runtime': (120578.14829110942, 73229.0189844461),
#  'CBS/(A*/SIC)': (111796.588418341, 59467.775908679505),
#  'Y Runtime': (33501.053074658594, 12238.692170066754),
#  'P Runtime': (79406.754382971, 31958.04352624875)}

# %%
runtime_per_algo
# Out:
# {'A*+OD+ID Runtime': 747591177.6856999,
#  'MA-CBS-Global-10/(EPEA*/SIC)': 1197149571.5674,
#  'Basic-CBS/(A*/SIC)': 1046827924.3706,
#  'ICTS 3E +ID Runtime': 634223302.2527,
#  'EPEA*+ID Runtime': 592276305.5462,
#  'CBS/(A*/SIC)': 480975371.54939985,
#  'Y Runtime': 98986542.2714999,
#  'P Runtime': 258476656.0402999}

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.bar(*zip(*runtime_per_algo.items()))
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# ## Let's visualize the success rate of our predicted alogrithm according to the oracle  ##

# %%
ax = plt.gca()
plt.rcParams["figure.figsize"] = (30,9)

for runtime_col in runtime_cols:
    print(runtime_to_success(runtime_col))
    s = X_test[X_test.NumOfAgents > 10]
#     s = s[s.NumOfAgents < 65]
    s = s.groupby("NumOfAgents")[runtime_to_success(runtime_col)].value_counts()
    s.to_frame()[s.index.to_frame()[runtime_to_success(runtime_col)] == 1][runtime_to_success(runtime_col)].plot(ax=ax)
    
ax.legend()
# Out:
# EPEA*+ID Success
# MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Success
# ICTS 3E +ID Success
# A*+OD+ID Success
# Basic-CBS/(A*/SIC)+ID Success
# Y Success
# P Success

# %% [markdown]
# ## FROM HERE ONLY RANDOM TESTS ##

# %%
runtime_cols
# Out:
# ['A*+OD+ID Runtime',
#  'MA-CBS-Global-10/(A*+OD/SIC) choosing the first conflict in CBS nodes Runtime',
#  'MA-CBS-Local-10/(single:A*/SIC multi:A*+OD/SIC) choosing the first conflict in CBS nodes Runtime',
#  'Basic-CBS/(A*+OD/SIC) choosing the first conflict in CBS nodes Runtime',
#  'MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime',
#  'MA-CBS-Local-10/(single:A*/SIC multi:EPEA*/SIC) choosing the first conflict in CBS nodes Runtime',
#  'Basic-CBS/(A*/SIC) choosing cardinal conflicts using lookahead Runtime',
#  'Basic-CBS/(A*/SIC)+ID Runtime',
#  'Y Runtime',
#  'P Runtime']

# %%
import numpy as np

features_cols = ['GridRows','GridColumns', 'NumOfAgents','NumOfObstacles',
            'BranchingFactor', 'ObstacleDensity', 'AvgDistanceToGoal', 'MaxDistanceToGoal', 'MinDistanceToGoal', 'AvgStartDistances', 'AvgGoalDistances',
              'PointsAtSPRatio', 'Sparsity']

feature_importance = xg_cls.feature_importances_
# make importances relative to max importance
feature_importance = 100.0 * (feature_importance / feature_importance.max())
print(feature_importance)
sorted_idx = np.argsort(feature_importance)
print(np.array(features_cols)[sorted_idx])
print(sorted_idx)
pos = np.arange(sorted_idx.shape[0]) + .5
plt.subplot(1, 2, 2)
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, np.array(features_cols)[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()
# Out:
# [ 29.7495    82.502815  32.871784 100.        21.343098  23.839773
#   21.230524  23.081902  24.000988  36.664284  93.174286]
# ['MaxDistanceToGoal' 'ObstacleDensity' 'MinDistanceToGoal'
#  'AvgDistanceToGoal' 'AvgStartDistances' 'GridRows' 'NumOfAgents'
#  'AvgGoalDistances' 'GridColumns' 'PointsAtSPRatio' 'NumOfObstacles']
# [ 6  4  7  5  8  0  2  9  1 10  3]

# %%
ax = plt.gca()
plt.rcParams["figure.figsize"] = (8,5)

pie_plt = df['Y'].value_counts().plot(kind='pie', legend=False, ax=ax)
pie_plt.set_ylabel('') #Removing column label from the plot
# Out:
# Text(0, 0.5, '')

# %%
den_df['Y'].value_counts()
# Out:
# A*+OD+ID Runtime                                                                                    9
# Basic-CBS/(A*/SIC)+ID Runtime                                                                       7
# MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime                       5
# MA-CBS-Local-10/(single:A*/SIC multi:A*+OD/SIC) choosing the first conflict in CBS nodes Runtime    3
# Basic-CBS/(A*/SIC) choosing cardinal conflicts using lookahead Runtime                              3
# MA-CBS-Local-10/(single:A*/SIC multi:EPEA*/SIC) choosing the first conflict in CBS nodes Runtime    2
# Name: Y, dtype: int64

# %%
pd.Series(y_pred).value_counts().plot(kind='pie')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-2e119c64e4ef> in <module>
# ----> 1 pd.Series(y_pred).value_counts().plot(kind='pie')
#
# NameError: name 'y_pred' is not defined

# %%
pd.Series(y_test).value_counts().plot(kind='pie')

# %%
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets.samples_generator import make_blobs
from sklearn.preprocessing import StandardScaler
X = X_train[features_cols]
X = StandardScaler().fit_transform(X)

db = DBSCAN(eps=0.1, min_samples=10).fit(X)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
print("Homogeneity: %0.3f" % metrics.homogeneity_score(y_train.values.transpose()[0], labels))
print("Completeness: %0.3f" % metrics.completeness_score(y_train.values.transpose()[0], labels))
print("V-measure: %0.3f" % metrics.v_measure_score(y_train.values.transpose()[0], labels))
print("Adjusted Rand Index: %0.3f"
      % metrics.adjusted_rand_score(y_train.values.transpose()[0], labels))
print("Adjusted Mutual Information: %0.3f"
      % metrics.adjusted_mutual_info_score(y_train.values.transpose()[0], labels,
                                           average_method='arithmetic'))
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(X, labels))

unique_labels = set(labels)
colors = [plt.cm.Spectral(each)
          for each in np.linspace(0, 1, len(unique_labels))]

for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = (labels == k)

    xy = X[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=14)

    xy = X[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=6)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()
# Out:
# Estimated number of clusters: 13
# Estimated number of noise points: 1408
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-683-4e406e8a4754> in <module>
#      16 print('Estimated number of clusters: %d' % n_clusters_)
#      17 print('Estimated number of noise points: %d' % n_noise_)
# ---> 18 print("Homogeneity: %0.3f" % metrics.homogeneity_score(y_train.values.transpose()[0], labels))
#      19 print("Completeness: %0.3f" % metrics.completeness_score(y_train.values.transpose()[0], labels))
#      20 print("V-measure: %0.3f" % metrics.v_measure_score(y_train.values.transpose()[0], labels))
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\cluster\supervised.py in homogeneity_score(labels_true, labels_pred)
#     388
#     389     """
# --> 390     return homogeneity_completeness_v_measure(labels_true, labels_pred)[0]
#     391
#     392
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\cluster\supervised.py in homogeneity_completeness_v_measure(labels_true, labels_pred)
#     294     v_measure_score
#     295     """
# --> 296     labels_true, labels_pred = check_clusterings(labels_true, labels_pred)
#     297
#     298     if len(labels_true) == 0:
#
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\cluster\supervised.py in check_clusterings(labels_true, labels_pred)
#      51     if labels_true.ndim != 1:
#      52         raise ValueError(
# ---> 53             "labels_true must be 1D: shape is %r" % (labels_true.shape,))
#      54     if labels_pred.ndim != 1:
#      55         raise ValueError(
#
# ValueError: labels_true must be 1D: shape is ()

# %%
# Code source: Gaël Varoquaux
# License: BSD 3 clause

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


from sklearn import decomposition
from sklearn import datasets

np.random.seed(5)

features_cols = ['GridRows','GridColumns', 'NumOfAgents','NumOfObstacles',
            'BranchingFactor', 'ObstacleDensity', 'AvgDistanceToGoal', 'MaxDistanceToGoal', 'MinDistanceToGoal', 'AvgStartDistances', 'AvgGoalDistances',
              'PointsAtSPRatio', 'Sparsity']

# features_cols = ['GridSize', 'NumOfObstacles',
#             'AvgDistanceToGoal', 'AvgStartDistances', 'AvgGoalDistances',
#             'NumOfAgents', 'ObstacleDensity']

# X = X_train[features_cols]
X = embed_df
# X = StandardScaler().fit_transform(X)

# y = y_train.values.transpose()[0]

fig = plt.figure(1, figsize=(4, 3))
# plt.clf()
# ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

# plt.cla()
pca = decomposition.PCA(n_components=2)
pca.fit(X)
X = pca.transform(X)

principalDf = pd.DataFrame(data = X
             , columns = ['principal component 1', 'principal component 2'])

finalDf = pd.concat([principalDf, y_train], axis = 1)


fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)

targets = only_alg_runtime_cols
import matplotlib.cm as cm

colors = cm.rainbow(np.linspace(0, 1, len(targets)))

for target, color in zip(targets,colors):
    indicesToKeep = finalDf['Y'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
def replace_label_with_int(x):
    return {
        'EPEA*+ID Runtime': 0,
        'MA-CBS-Global-10/(EPEA*/SIC) choosing the first conflict in CBS nodes Runtime':1,
        'ICTS 3E +ID Runtime':2,
        'A*+OD+ID Runtime':3,
        'Basic-CBS/(A*/SIC)+ID Runtime':4
    }[x]

# %%
features_cols = ['GridRows','GridColumns', 'NumOfAgents','NumOfObstacles',
            'BranchingFactor', 'ObstacleDensity', 'AvgDistanceToGoal', 'MaxDistanceToGoal', 'MinDistanceToGoal', 'AvgStartDistances', 'AvgGoalDistances',
              'PointsAtSPRatio', 'Sparsity']


X = X_train[features_cols]
X = StandardScaler().fit_transform(X)

y = y_train.values.transpose()

fig = plt.figure(1, figsize=(6, 6))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=30, azim=134)

plt.cla()
pca = decomposition.PCA(n_components=3)
pca.fit(X)
X = pca.transform(X)

targets = only_alg_runtime_cols
import matplotlib.cm as cm

# colors = cm.rainbow(np.linspace(0, 1, len(targets)))
colors = []
for label, name in enumerate(targets):
    ax.text3D(X[y == name, 0].mean(),
              X[y == name, 1].mean() + 1.5,
              X[y == name, 2].mean(),
              name[:5],
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))

# Reorder the labels to have colors matching the cluster results
y = [replace_label_with_int(label) for label in y]
y = np.choose(y, [1, 2, 3, 4, 0]).astype(np.float)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap=plt.cm.nipy_spectral,
           edgecolor='k')

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])

plt.show()
# Out:
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
from sklearn.decomposition import PCA, KernelPCA

features_cols = ['GridRows','GridColumns', 'NumOfAgents','NumOfObstacles',
            'BranchingFactor', 'ObstacleDensity', 'AvgDistanceToGoal', 'MaxDistanceToGoal', 'MinDistanceToGoal', 'AvgStartDistances', 'AvgGoalDistances',
              'PointsAtSPRatio', 'Sparsity']

X = X_train[features_cols]
X = StandardScaler().fit_transform(X)

y = y_train.values.transpose()

kpca = KernelPCA(kernel="rbf", fit_inverse_transform=True, gamma=10)


X_kpca = kpca.fit_transform(X)
y = [replace_label_with_int(label) for label in y]
y = np.array(y)
reds = y == 0
blues = y == 1
oranges = y == 2
greens = y == 3
pinks = y == 4

# plt.subplot(2, 2, 3, aspect='equal')
plt.scatter(X_kpca[reds, 0], X_kpca[reds, 1], c="red",
            s=20, edgecolor='k')
plt.scatter(X_kpca[blues, 0], X_kpca[blues, 1], c="blue",
            s=20, edgecolor='k')
plt.scatter(X_kpca[oranges, 0], X_kpca[oranges, 1], c="orange",
            s=20, edgecolor='k')
plt.scatter(X_kpca[greens, 0], X_kpca[greens, 1], c="green",
            s=20, edgecolor='k')
plt.scatter(X_kpca[pinks, 0], X_kpca[pinks, 1], c="pink",
            s=20, edgecolor='k')

# y = np.choose(y, [1, 2, 3, 4, 0]).astype(np.float)
# plt.scatter(X_kpca[:, 0], X_kpca[:, 1], c=y, edgecolor='k')

plt.title("Projection by KPCA")
plt.xlabel(r"1st principal component in space induced by $\phi$")
plt.ylabel("2nd component")

plt.show()
# Out:
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# c:\users\omri\appdata\local\programs\python\python36\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
